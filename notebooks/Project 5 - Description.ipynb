# %% [markdown]
# ### Project 5

# %% [markdown]
# #### Goal 1

# %% [markdown]
# For this goal, you are given a number of CSV files, each of which have their first row with the field name.
#
# You goal is to create a context manager that you can use to produce the data from each file in a named tuple with field names corresponding to the  header row field names.
#
# You should use the `csv` module's `reader` function to help with parsing the data.
#
# Your context manager should be generic in the sense that it should just need the file name, no other configuration or hardcoded functionality is required. You do not need to worry about data types for this goal - just return every field as a string.
#
# In addition, your context manager should produce lazy iterators.
#
# Implement this using a class that implements the context manager protocol

# %% [markdown]
# #### Goal 2

# %% [markdown]
# The goal is to reproduce the work you did in Goal 1, but using a generator function and the `contextlib` `contextmanager` decorator.

# %% [markdown]
# ### Notes

# %% [markdown]
# The files included with this project are:
# * `cars.csv`
# * `personal_info.csv`

# %% [markdown]
# In addition you might find the following useful.

# %% [markdown]
# ##### Reading and rewinding data from a File

# %% [markdown]
# The file object supports reading data by specifying the amount of data we want to read, and repositioning the "read head" using the `seek` function.
#
# Let's take a look:

# %%
with open('cars.csv') as f:
    print('---', f.read(100))
    print('---', f.read(100))
    f.seek(0)
    print('---', f.read(100))
# Out:
# --- Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# Chevrolet Chevelle Malibu
# --- ;18.0;8;307.0;130.0;3504.;12.0;70;US
# Buick Skylark 320;15.0;8;350.0;165.0;3693.;11.5;70;US
# Plymouth
# --- Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# Chevrolet Chevelle Malibu

# %% [markdown]
# As you can see, we could read the file calling the `read` method - this reads data and advances the "read head". We can then rewind and start again - either reading directly, or even just iterating through the rows using the iterator:

# %%
from itertools import islice

with open('cars.csv') as f:
    print('---', f.read(100))
    print('---', f.read(100))
    print('--------------------')
    print('rewinding to 0...')
    f.seek(0)
    for row in islice(f, 5):
        print(row, end='')
# Out:
# --- Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# Chevrolet Chevelle Malibu
# --- ;18.0;8;307.0;130.0;3504.;12.0;70;US
# Buick Skylark 320;15.0;8;350.0;165.0;3693.;11.5;70;US
# Plymouth
# --------------------
# rewinding to 0...
# Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3504.;12.0;70;US
# Buick Skylark 320;15.0;8;350.0;165.0;3693.;11.5;70;US
# Plymouth Satellite;18.0;8;318.0;150.0;3436.;11.0;70;US
# AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US

# %% [markdown]
# ##### Sniffing the CSV dialect

# %% [markdown]
# The dialect of a CSV file refers to some of the specifics used to define data in a CSV file. The separators can be different (for example some failes use a comma, some use a semi-colon, some use a tab, etc).
#
# Also, as we have seen before, a field is also sometimes delimited using quotes, or double quotes, or maybe some entirely different character.
#
# When we have to deal with files that may be encoded using different dialects it can require quite a bit of work to determine what those specifics are. This is were the `Sniffer` class from the `csv` module can be useful. By providing it a sample fo the CSV file, it can analyze it and determine a best guess as to the specific dialect that was used. We can then use that dialect when we use the `csv.reader` function.
#
# Let's see how to use it with one of our files: `personal_info.csv`:

# %%
import csv

with open('personal_info.csv') as f:
    sample = f.read(2000)
    dialect = csv.Sniffer().sniff(sample)
print(vars(dialect))
# Out:
# {'__module__': 'csv', '_name': 'sniffed', 'lineterminator': '\r\n', 'quoting': 0, '__doc__': None, 'doublequote': False, 'delimiter': ',', 'quotechar': '"', 'skipinitialspace': False}

# %% [markdown]
# We can now use this dialect to open the csv reader:

# %%
with open('personal_info.csv') as f:
    reader = csv.reader(f, dialect)
    for row in islice(reader, 5):
        print(row)
# Out:
# ['ssn', 'first_name', 'last_name', 'gender', 'language']
# ['100-53-9824', 'Sebastiano', 'Tester', 'Male', 'Icelandic']
# ['101-71-4702', 'Cayla', 'MacDonagh', 'Female', 'Lao']
# ['101-84-0356', 'Nomi', 'Lipprose', 'Female', 'Yiddish']
# ['104-22-0928', 'Justinian', 'Kunzelmann', 'Male', 'Dhivehi']

# %%
# Goal 1

# %%
import csv
from collections import namedtuple

# %%
class FileParser:
    def __init__(self, f_name):
        self.f_name = f_name
        
    def __enter__(self):
        f = open(self.f_name)
        dialect = csv.Sniffer().sniff(f.read(1024))
        f.seek(0)
        self.csvreader = csv.reader(f, dialect)
        fieldnames = ['_'.join(fieldname.lower().split()) for fieldname in next(self.csvreader)]
        self.Record = namedtuple('Record', fieldnames, rename=True)
        return self
    
    def __exit__(self, exc_type, exc_value, traceback):
        f.close()
    
    def __iter__(self):
        return self
    
    def __next__(self):
        return self.Record(*next(self.csvreader))

# %%
from itertools import islice

with FileParser('cars.csv') as data:
    for row in islice(data, 10):
        print(row)
# Out:
# Record(car='Chevrolet Chevelle Malibu', mpg='18.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='3504.', acceleration='12.0', model='70', origin='US')
# Record(car='Buick Skylark 320', mpg='15.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='3693.', acceleration='11.5', model='70', origin='US')
# Record(car='Plymouth Satellite', mpg='18.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3436.', acceleration='11.0', model='70', origin='US')
# Record(car='AMC Rebel SST', mpg='16.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3433.', acceleration='12.0', model='70', origin='US')
# Record(car='Ford Torino', mpg='17.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3449.', acceleration='10.5', model='70', origin='US')
# Record(car='Ford Galaxie 500', mpg='15.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4341.', acceleration='10.0', model='70', origin='US')
# Record(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='454.0', horsepower='220.0', weight='4354.', acceleration='9.0', model='70', origin='US')
# Record(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4312.', acceleration='8.5', model='70', origin='US')
# Record(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4425.', acceleration='10.0', model='70', origin='US')
# Record(car='AMC Ambassador DPL', mpg='15.0', cylinders='8', displacement='390.0', horsepower='190.0', weight='3850.', acceleration='8.5', model='70', origin='US')

# %%
with FileParser('personal_info.csv') as data:
    for row in data:
        print(row)
# Out:
# Record(ssn='100-53-9824', first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic')
# Record(ssn='101-71-4702', first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao')
# Record(ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish')
# Record(ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi')
# Record(ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans')
# Record(ssn='105-27-5541', first_name='Federico', last_name='Aggett', gender='Male', language='Chinese')
# Record(ssn='105-85-7486', first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi')
# Record(ssn='105-91-5022', first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian')
# Record(ssn='105-91-7777', first_name='Audi', last_name='Roach', gender='Female', language='Estonian')
# Record(ssn='106-35-1938', first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish')
# Record(ssn='106-36-3293', first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin')
# Record(ssn='110-84-3641', first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento')
# Record(ssn='111-35-1034', first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz')
# Record(ssn='114-06-6912', first_name='Jule', last_name='Velte', gender='Male', language='Dutch')
# Record(ssn='114-66-0984', first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian')
# Record(ssn='114-74-8701', first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic')
# Record(ssn='116-10-7235', first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari')
# Record(ssn='116-77-4915', first_name='Herold', last_name='Fearon', gender='Male', language='Italian')
# Record(ssn='117-39-6617', first_name='Auroora', last_name='Yong', gender='Female', language='Swahili')
# Record(ssn='117-77-9748', first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew')
# Record(ssn='117-78-6202', first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish')
# Record(ssn='118-21-0357', first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian')
# Record(ssn='118-95-7100', first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian')
# Record(ssn='119-07-8817', first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian')
# Record(ssn='120-33-5535', first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi')
# Record(ssn='120-98-4054', first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh')
# Record(ssn='121-98-3948', first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian')
# Record(ssn='123-05-3229', first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian')
# Record(ssn='123-62-2832', first_name='Kare', last_name='Barhams', gender='Female', language='Tajik')
# Record(ssn='123-88-3381', first_name='Christiane', last_name='Hynes', gender='Female', language='Danish')
# Record(ssn='125-07-9434', first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian')
# Record(ssn='127-49-2473', first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole')
# Record(ssn='127-52-8001', first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara')
# Record(ssn='127-68-4232', first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic')
# Record(ssn='127-93-3548', first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao')
# Record(ssn='128-42-4599', first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian')
# Record(ssn='128-53-0369', first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian')
# Record(ssn='128-53-7952', first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish')
# Record(ssn='128-56-6040', first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian')
# Record(ssn='128-60-4388', first_name='Norton', last_name='Shailer', gender='Male', language='Czech')
# Record(ssn='129-67-0291', first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha')
# Record(ssn='131-81-4310', first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish')
# Record(ssn='132-26-3507', first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi')
# Record(ssn='134-05-0120', first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino')
# Record(ssn='135-86-9625', first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz')
# Record(ssn='137-13-1889', first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama')
# Record(ssn='138-65-4579', first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish')
# Record(ssn='138-67-1198', first_name='Pam', last_name='Tofful', gender='Female', language='Bislama')
# Record(ssn='138-88-5288', first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese')
# Record(ssn='139-04-8189', first_name='Stirling', last_name='Creak', gender='Male', language='Italian')
# Record(ssn='139-94-5865', first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole')
# Record(ssn='139-99-6417', first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi')
# Record(ssn='140-33-9727', first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian')
# Record(ssn='140-58-8263', first_name='Tim', last_name='Bergin', gender='Female', language='Maori')
# Record(ssn='141-15-0543', first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin')
# Record(ssn='141-88-9721', first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana')
# Record(ssn='142-77-4616', first_name='Barron', last_name='Victoria', gender='Male', language='Assamese')
# Record(ssn='142-87-3416', first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik')
# Record(ssn='143-17-4714', first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek')
# Record(ssn='145-10-8454', first_name='Donny', last_name='Laba', gender='Male', language='Japanese')
# Record(ssn='145-35-5124', first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi')
# Record(ssn='145-78-3985', first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian')
# Record(ssn='146-81-3446', first_name='Korry', last_name='Billham', gender='Female', language='Hebrew')
# Record(ssn='147-33-1463', first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento')
# Record(ssn='147-47-8577', first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati')
# Record(ssn='147-63-3462', first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin')
# Record(ssn='148-60-7519', first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer')
# Record(ssn='149-18-7272', first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento')
# Record(ssn='149-45-6482', first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian')
# Record(ssn='150-64-6357', first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian')
# Record(ssn='150-89-3343', first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha')
# Record(ssn='151-54-3946', first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali')
# Record(ssn='151-70-0641', first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy')
# Record(ssn='151-78-1397', first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho')
# Record(ssn='152-71-3526', first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish')
# Record(ssn='153-67-1309', first_name='Annelise', last_name='Yushin', gender='Female', language='French')
# Record(ssn='154-17-7912', first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi')
# Record(ssn='156-18-7547', first_name='Trey', last_name='Payne', gender='Male', language='West Frisian')
# Record(ssn='156-91-6848', first_name='Carol', last_name='Cromar', gender='Female', language='Amharic')
# Record(ssn='157-17-9982', first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish')
# Record(ssn='157-38-7090', first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans')
# Record(ssn='157-51-5269', first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi')
# Record(ssn='161-36-9710', first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish')
# Record(ssn='161-53-4778', first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz')
# Record(ssn='163-68-8070', first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino')
# Record(ssn='163-98-1022', first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian')
# Record(ssn='164-11-9849', first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian')
# Record(ssn='166-10-4488', first_name='Lester', last_name='Keyson', gender='Male', language='Bislama')
# Record(ssn='167-39-2377', first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese')
# Record(ssn='168-02-5324', first_name='Dane', last_name='Cornick', gender='Male', language='Tajik')
# Record(ssn='168-19-8754', first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian')
# Record(ssn='168-81-0838', first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara')
# Record(ssn='168-89-6661', first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum')
# Record(ssn='170-65-3388', first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese')
# Record(ssn='171-27-7781', first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao')
# Record(ssn='172-23-7739', first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz')
# Record(ssn='172-77-4263', first_name='Alex', last_name='Udie', gender='Male', language='French')
# Record(ssn='172-89-7546', first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian')
# Record(ssn='173-99-7372', first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish')
# Record(ssn='174-13-2047', first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu')
# Record(ssn='174-35-3812', first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz')
# Record(ssn='174-51-9992', first_name='Drucie', last_name='Travers', gender='Female', language='Swati')
# Record(ssn='174-87-2537', first_name='Benton', last_name='Nolte', gender='Male', language='Persian')
# Record(ssn='176-82-1359', first_name='Corny', last_name='Rothera', gender='Female', language='Thai')
# Record(ssn='176-99-5851', first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan')
# Record(ssn='179-88-2790', first_name='Errick', last_name='Charsley', gender='Male', language='Japanese')
# Record(ssn='181-07-4434', first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan')
# Record(ssn='181-28-8337', first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan')
# Record(ssn='181-88-6077', first_name='Ebba', last_name='Wozencroft', gender='Female', language='German')
# Record(ssn='182-15-5082', first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili')
# Record(ssn='182-81-4541', first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish')
# Record(ssn='183-10-5024', first_name='Curran', last_name='Squires', gender='Male', language='Romanian')
# Record(ssn='184-60-6243', first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin')
# Record(ssn='184-84-1003', first_name='Bary', last_name='Buzin', gender='Male', language='Aymara')
# Record(ssn='184-92-3560', first_name='Kore', last_name='Eastes', gender='Female', language='Fijian')
# Record(ssn='184-94-5241', first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati')
# Record(ssn='185-50-0434', first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua')
# Record(ssn='185-84-9868', first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho')
# Record(ssn='186-65-7773', first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi')
# Record(ssn='188-20-9317', first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai')
# Record(ssn='188-40-4336', first_name='Belita', last_name='Camolli', gender='Female', language='Telugu')
# Record(ssn='189-26-5696', first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin')
# Record(ssn='189-49-1458', first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua')
# Record(ssn='190-05-6987', first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian')
# Record(ssn='190-53-4517', first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili')
# Record(ssn='191-15-3194', first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai')
# Record(ssn='192-54-0695', first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori')
# Record(ssn='192-67-3201', first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew')
# Record(ssn='194-76-5816', first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic')
# Record(ssn='195-23-5731', first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese')
# Record(ssn='196-69-3796', first_name='Marijo', last_name='Tester', gender='Female', language='Oriya')
# Record(ssn='198-70-6443', first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian')
# Record(ssn='199-45-0804', first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana')
# Record(ssn='199-54-4639', first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali')
# Record(ssn='200-81-7151', first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali')
# Record(ssn='201-53-1249', first_name='Jammal', last_name='Dohmer', gender='Male', language='Danish')
# Record(ssn='202-84-1146', first_name='Dore', last_name='Woodrup', gender='Male', language='Afrikaans')
# Record(ssn='203-35-7648', first_name='Budd', last_name='Artiss', gender='Male', language='Norwegian')
# Record(ssn='205-69-7375', first_name='Cacilia', last_name='Kneesha', gender='Female', language='Indonesian')
# Record(ssn='205-87-2423', first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu')
# Record(ssn='206-28-6674', first_name='Con', last_name='Mansbridge', gender='Male', language='Haitian Creole')
# Record(ssn='206-83-8848', first_name='Ardyth', last_name='Arger', gender='Female', language='Gagauz')
# Record(ssn='208-74-2166', first_name='Tiebold', last_name='Gherarducci', gender='Male', language='Croatian')
# Record(ssn='208-80-5879', first_name='Rockie', last_name='Fryd', gender='Male', language='Korean')
# Record(ssn='209-50-8146', first_name='Kenna', last_name='Meryett', gender='Female', language='Czech')
# Record(ssn='209-58-4708', first_name='Stephanus', last_name='Creboe', gender='Male', language='Latvian')
# Record(ssn='210-91-4729', first_name='Tamarra', last_name='Minchella', gender='Female', language='Greek')
# Record(ssn='211-04-1734', first_name='Jeana', last_name='Girardeau', gender='Female', language='Dzongkha')
# Record(ssn='211-13-5247', first_name='Wes', last_name='Weinberg', gender='Male', language='French')
# Record(ssn='211-15-5182', first_name='Gene', last_name='Bassilashvili', gender='Female', language='Swedish')
# Record(ssn='211-19-6826', first_name='Noni', last_name='Meynell', gender='Female', language='Portuguese')
# Record(ssn='212-40-0215', first_name='Giffie', last_name='Strauss', gender='Male', language='Azeri')
# Record(ssn='212-41-1496', first_name='Agnese', last_name='Lawes', gender='Female', language='Tamil')
# Record(ssn='213-28-1395', first_name='Catlaina', last_name='Patullo', gender='Female', language='Bengali')
# Record(ssn='214-29-1189', first_name='Chandler', last_name='Gonsalvo', gender='Male', language='Haitian Creole')
# Record(ssn='214-96-8581', first_name='Earlie', last_name='de Nore', gender='Male', language='Georgian')
# Record(ssn='214-99-7584', first_name='Barny', last_name='Witherden', gender='Male', language='Czech')
# Record(ssn='216-89-3812', first_name='Florian', last_name='Jaze', gender='Male', language='Croatian')
# Record(ssn='216-97-3104', first_name='Elvira', last_name='McDougal', gender='Female', language='Bislama')
# Record(ssn='217-71-3922', first_name='Hayes', last_name='Vallentin', gender='Male', language='Bengali')
# Record(ssn='217-81-5416', first_name='Gusta', last_name='Cruise', gender='Female', language='Tsonga')
# Record(ssn='218-14-4448', first_name='Keary', last_name='Druhan', gender='Male', language='Dutch')
# Record(ssn='218-25-9873', first_name='Westbrooke', last_name='Succamore', gender='Male', language='Fijian')
# Record(ssn='218-31-1615', first_name='Trenton', last_name='Eggerton', gender='Male', language='Dari')
# Record(ssn='218-49-7300', first_name='Justinn', last_name='Sherebrooke', gender='Female', language='English')
# Record(ssn='220-16-0476', first_name='Baxy', last_name='Brothwood', gender='Male', language='Kyrgyz')
# Record(ssn='220-38-0208', first_name='Jess', last_name='Fulun', gender='Female', language='Gagauz')
# Record(ssn='222-39-8571', first_name='Fidelia', last_name='Domonkos', gender='Female', language='Fijian')
# Record(ssn='223-67-9203', first_name='Markus', last_name='Radband', gender='Male', language='Bosnian')
# Record(ssn='223-98-0846', first_name='Josy', last_name='Hadwick', gender='Female', language='Papiamento')
# Record(ssn='224-12-3436', first_name='Alister', last_name='Eakle', gender='Male', language='Estonian')
# Record(ssn='224-30-9267', first_name='Flori', last_name='Bagnal', gender='Female', language='Swedish')
# Record(ssn='224-54-6919', first_name='Kelly', last_name='Shipman', gender='Male', language='Icelandic')
# Record(ssn='224-84-2271', first_name='Weider', last_name='Carlisle', gender='Male', language='Swedish')
# Record(ssn='224-99-0668', first_name='Brandy', last_name='Steed', gender='Male', language='Croatian')
# Record(ssn='225-08-5789', first_name='Tamra', last_name='Becken', gender='Female', language='Telugu')
# Record(ssn='225-64-2735', first_name='Graig', last_name='Rasher', gender='Male', language='Maltese')
# Record(ssn='226-76-4452', first_name='Van', last_name='Gervaise', gender='Male', language='Greek')
# Record(ssn='227-72-7247', first_name='Mauricio', last_name='Gush', gender='Male', language='Tajik')
# Record(ssn='228-16-7922', first_name='Tabby', last_name='Chitty', gender='Male', language='Spanish')
# Record(ssn='228-55-2042', first_name='Jaquith', last_name='Durtnel', gender='Female', language='Czech')
# Record(ssn='228-90-5077', first_name='Jonathon', last_name='Klugel', gender='Male', language='Hindi')
# Record(ssn='229-44-9909', first_name='Barnabas', last_name='Heppenspall', gender='Male', language='Icelandic')
# Record(ssn='230-09-1794', first_name='Xerxes', last_name='Mathivon', gender='Male', language='Danish')
# Record(ssn='230-48-0684', first_name='Clay', last_name='Peaurt', gender='Male', language='Dhivehi')
# Record(ssn='230-99-1485', first_name='Markus', last_name='Revill', gender='Male', language='Moldovan')
# Record(ssn='231-66-9264', first_name='Gisele', last_name='Castelow', gender='Female', language='Hiri Motu')
# Record(ssn='232-18-5397', first_name='Clare', last_name='McGairl', gender='Female', language='Bengali')
# Record(ssn='233-27-2377', first_name='Arlyne', last_name='Stenning', gender='Female', language='Dari')
# Record(ssn='235-10-3518', first_name='Winfield', last_name='Purvis', gender='Male', language='Estonian')
# Record(ssn='236-31-8333', first_name='Wendeline', last_name='Millins', gender='Female', language='Kashmiri')
# Record(ssn='236-37-2567', first_name='Ariel', last_name='Murrigan', gender='Female', language='West Frisian')
# Record(ssn='237-48-6737', first_name='Eal', last_name='Ducastel', gender='Male', language='Indonesian')
# Record(ssn='237-80-7039', first_name='Ardyce', last_name='Hunn', gender='Female', language='Maltese')
# Record(ssn='238-13-8034', first_name='Estrellita', last_name='Heavy', gender='Female', language='Azeri')
# Record(ssn='238-39-9999', first_name='Pauly', last_name='Griffin', gender='Female', language='Georgian')
# Record(ssn='239-09-9133', first_name='Tom', last_name='Roggeman', gender='Male', language='Sotho')
# Record(ssn='239-37-4122', first_name='Jodee', last_name='Elsdon', gender='Female', language='Guarana')
# Record(ssn='240-08-8805', first_name='Gates', last_name='McGiffin', gender='Female', language='Finnish')
# Record(ssn='240-32-8915', first_name='Cathee', last_name='Tarbard', gender='Female', language='Papiamento')
# Record(ssn='240-67-6258', first_name='Kalina', last_name='Lloyds', gender='Female', language='Hindi')
# Record(ssn='242-22-9624', first_name='Felice', last_name='Surr', gender='Male', language='Afrikaans')
# Record(ssn='243-37-9496', first_name='Verine', last_name='Etchells', gender='Female', language='Burmese')
# Record(ssn='243-44-4611', first_name='Shani', last_name="O'Tierney", gender='Female', language='Aymara')
# Record(ssn='244-34-2210', first_name='Lek', last_name='Heino', gender='Male', language='New Zealand Sign Language')
# Record(ssn='244-52-7593', first_name='Erda', last_name='Paulusch', gender='Female', language='Gujarati')
# Record(ssn='244-79-3004', first_name='Renault', last_name='Stollard', gender='Male', language='Amharic')
# Record(ssn='244-81-0671', first_name='Viviyan', last_name='Udell', gender='Female', language='Moldovan')
# Record(ssn='245-60-5880', first_name='Oby', last_name='Hauxby', gender='Male', language='French')
# Record(ssn='245-77-4110', first_name='Alasdair', last_name='McAndrew', gender='Male', language='Czech')
# Record(ssn='247-08-9326', first_name='Minni', last_name='Scurman', gender='Female', language='Kannada')
# Record(ssn='247-86-5288', first_name='Lilly', last_name='Holby', gender='Female', language='Bosnian')
# Record(ssn='248-07-9757', first_name='Sean', last_name='Ham', gender='Male', language='Luxembourgish')
# Record(ssn='248-23-0150', first_name='Welbie', last_name='Gilley', gender='Male', language='Korean')
# Record(ssn='249-19-5514', first_name='Yehudi', last_name='Pharoah', gender='Male', language='Latvian')
# Record(ssn='253-61-8401', first_name='Genny', last_name='Juara', gender='Female', language='Tswana')
# Record(ssn='254-10-6071', first_name='Dwight', last_name='Eastcourt', gender='Male', language='Oriya')
# Record(ssn='254-92-9669', first_name='Tom', last_name='Larking', gender='Male', language='Icelandic')
# Record(ssn='255-81-0958', first_name='Darryl', last_name='Sparkes', gender='Female', language='Estonian')
# Record(ssn='256-54-7507', first_name='Angus', last_name='Cullip', gender='Male', language='Spanish')
# Record(ssn='256-57-0666', first_name='Rip', last_name='Grube', gender='Male', language='Ndebele')
# Record(ssn='257-12-6834', first_name='Derward', last_name='Paladini', gender='Male', language='Thai')
# Record(ssn='257-59-8603', first_name='Cyrillus', last_name='Sanchiz', gender='Male', language='Romanian')
# Record(ssn='257-77-3669', first_name='Ynez', last_name='Hain', gender='Female', language='Kazakh')
# Record(ssn='258-22-6416', first_name='Veriee', last_name='Klein', gender='Female', language='Northern Sotho')
# Record(ssn='259-38-5920', first_name='Jethro', last_name='Rustidge', gender='Male', language='Fijian')
# Record(ssn='261-14-9490', first_name='Lorry', last_name='Boshere', gender='Male', language='Oriya')
# Record(ssn='262-09-2144', first_name='Leigh', last_name='Paxforde', gender='Male', language='Portuguese')
# Record(ssn='262-46-7573', first_name='Lorene', last_name='Vagg', gender='Female', language='Punjabi')
# Record(ssn='262-55-4066', first_name='Kaitlynn', last_name='Bleazard', gender='Female', language='Estonian')
# Record(ssn='262-66-7030', first_name='Gray', last_name='Bissatt', gender='Female', language='Khmer')
# Record(ssn='264-39-3910', first_name='Elysia', last_name='Favell', gender='Female', language='Hindi')
# Record(ssn='266-86-9980', first_name='Rita', last_name='Leving', gender='Female', language='Latvian')
# Record(ssn='267-75-6383', first_name='Ardath', last_name='Pitts', gender='Female', language='Romanian')
# Record(ssn='269-01-2640', first_name='Russell', last_name='Dabner', gender='Male', language='Danish')
# Record(ssn='271-04-0134', first_name='Eadith', last_name='Jerg', gender='Female', language='Gagauz')
# Record(ssn='271-81-9938', first_name='James', last_name='Robbins', gender='Male', language='Bengali')
# Record(ssn='271-93-3051', first_name='Augustin', last_name='Agiolfinger', gender='Male', language='Latvian')
# Record(ssn='272-50-7309', first_name='Sig', last_name='Ather', gender='Male', language='Catalan')
# Record(ssn='272-81-7979', first_name='Sherlocke', last_name='Giddings', gender='Male', language='Georgian')
# Record(ssn='273-49-8218', first_name='Haze', last_name='Starkings', gender='Male', language='Portuguese')
# Record(ssn='274-50-3806', first_name='Shurlocke', last_name='Aron', gender='Male', language='Punjabi')
# Record(ssn='274-76-9883', first_name='Fawn', last_name='MacNamara', gender='Female', language='Bengali')
# Record(ssn='276-05-2973', first_name='Cly', last_name='Yerlett', gender='Male', language='Kazakh')
# Record(ssn='278-55-5842', first_name='Korie', last_name='Di Pietro', gender='Female', language='German')
# Record(ssn='278-64-4853', first_name='Diane-marie', last_name='Broggini', gender='Female', language='Tsonga')
# Record(ssn='279-12-7167', first_name='Elbertina', last_name='Alders', gender='Female', language='Amharic')
# Record(ssn='279-40-5540', first_name='Montague', last_name='Knowler', gender='Male', language='Chinese')
# Record(ssn='279-49-5682', first_name='Kleon', last_name='Tembridge', gender='Male', language='Gagauz')
# Record(ssn='280-53-7447', first_name='Suzette', last_name='Prahl', gender='Female', language='Romanian')
# Record(ssn='280-98-4410', first_name='Ealasaid', last_name='Devon', gender='Female', language='Tok Pisin')
# Record(ssn='281-23-3458', first_name='Bettina', last_name='Danilov', gender='Female', language='Sotho')
# Record(ssn='282-83-9206', first_name='Jackie', last_name='McPhater', gender='Male', language='Gagauz')
# Record(ssn='283-04-6835', first_name='Tobey', last_name='Joule', gender='Female', language='Dzongkha')
# Record(ssn='286-26-4004', first_name='Augustus', last_name='Doodson', gender='Male', language='Romanian')
# Record(ssn='287-57-9688', first_name='Joachim', last_name='Moncreiff', gender='Male', language='Catalan')
# Record(ssn='287-66-2660', first_name='Larissa', last_name='Airy', gender='Female', language='Bislama')
# Record(ssn='288-54-7233', first_name='Hedy', last_name='Eaklee', gender='Female', language='English')
# Record(ssn='288-87-6462', first_name='Stanislaus', last_name='Haylor', gender='Male', language='Kannada')
# Record(ssn='289-03-9882', first_name='Giusto', last_name='Baszniak', gender='Male', language='Yiddish')
# Record(ssn='289-09-8686', first_name='Heath', last_name='Stallan', gender='Male', language='Malayalam')
# Record(ssn='290-25-7300', first_name='Bowie', last_name='Bancroft', gender='Male', language='Thai')
# Record(ssn='290-82-4968', first_name='Ingram', last_name='Kincade', gender='Male', language='Moldovan')
# Record(ssn='293-54-3694', first_name='Theodora', last_name='Geddes', gender='Female', language='Maori')
# Record(ssn='294-27-9936', first_name='Cari', last_name='Bradane', gender='Female', language='Japanese')
# Record(ssn='294-53-1911', first_name='Ginelle', last_name='Jaquet', gender='Female', language='Persian')
# Record(ssn='295-63-7693', first_name='Fonzie', last_name='Fattorini', gender='Male', language='Estonian')
# Record(ssn='296-32-7910', first_name='Harlene', last_name='Morrill', gender='Female', language='Swati')
# Record(ssn='296-88-0097', first_name='Herculie', last_name='Branthwaite', gender='Male', language='Hungarian')
# Record(ssn='296-90-4908', first_name='Holt', last_name='Angel', gender='Male', language='Tamil')
# Record(ssn='297-63-1154', first_name='Maribelle', last_name='Gowanson', gender='Female', language='Montenegrin')
# Record(ssn='298-06-3497', first_name='Moshe', last_name='Thomassin', gender='Male', language='Polish')
# Record(ssn='298-69-9168', first_name='Shea', last_name='Canon', gender='Male', language='Finnish')
# Record(ssn='298-70-6018', first_name='Minny', last_name='Van der Baaren', gender='Female', language='Afrikaans')
# Record(ssn='298-79-7640', first_name='Mycah', last_name='Hillam', gender='Male', language='Swahili')
# Record(ssn='299-03-6911', first_name='Janela', last_name='Ferrone', gender='Female', language='Gagauz')
# Record(ssn='299-38-0483', first_name='Robb', last_name='Posner', gender='Male', language='Italian')
# Record(ssn='299-77-1060', first_name='Bellina', last_name='Galbreth', gender='Female', language='Norwegian')
# Record(ssn='300-59-3610', first_name='Tam', last_name='Howles', gender='Male', language='Pashto')
# Record(ssn='300-76-8770', first_name='Danielle', last_name='Rowth', gender='Female', language='Italian')
# Record(ssn='300-80-7209', first_name='Gabbie', last_name='Burney', gender='Female', language='Dutch')
# Record(ssn='301-26-4306', first_name='Emmye', last_name='Whelpdale', gender='Female', language='Tajik')
# Record(ssn='301-51-0522', first_name='Kenneth', last_name='Methley', gender='Male', language='Papiamento')
# Record(ssn='302-64-4858', first_name='Hakeem', last_name='Zelley', gender='Male', language='Afrikaans')
# Record(ssn='304-48-4312', first_name='Edeline', last_name='Van de Vlies', gender='Female', language='Montenegrin')
# Record(ssn='305-07-1498', first_name='Ruddy', last_name="O'Crotty", gender='Male', language='Spanish')
# Record(ssn='306-23-2423', first_name='Ree', last_name='Meader', gender='Female', language='Polish')
# Record(ssn='306-86-2930', first_name='Kassie', last_name='Neaverson', gender='Female', language='Luxembourgish')
# Record(ssn='308-58-0964', first_name='Talbert', last_name='Osipov', gender='Male', language='Tetum')
# Record(ssn='309-04-0364', first_name='Dov', last_name='Speight', gender='Male', language='Tajik')
# Record(ssn='309-38-8085', first_name='Nell', last_name='Scrigmour', gender='Female', language='Persian')
# Record(ssn='310-60-2027', first_name='Zacherie', last_name='Parken', gender='Male', language='Albanian')
# Record(ssn='311-46-9296', first_name='Alic', last_name='Pabel', gender='Male', language='Fijian')
# Record(ssn='312-38-7084', first_name='Ezri', last_name='Paolicchi', gender='Male', language='Malagasy')
# Record(ssn='312-59-3476', first_name='Sadye', last_name='Beloe', gender='Female', language='Icelandic')
# Record(ssn='312-77-3647', first_name='Hussein', last_name='Blything', gender='Male', language='Hebrew')
# Record(ssn='313-02-7822', first_name='Spence', last_name='Climer', gender='Male', language='Maori')
# Record(ssn='313-52-7312', first_name='Farrand', last_name='MacKenzie', gender='Female', language='French')
# Record(ssn='315-12-5664', first_name='Vere', last_name='Morlon', gender='Female', language='German')
# Record(ssn='315-26-2241', first_name='Cammy', last_name='Harland', gender='Female', language='Bulgarian')
# Record(ssn='315-44-9671', first_name='Ximenez', last_name='Maghull', gender='Male', language='Macedonian')
# Record(ssn='315-78-5587', first_name='Helsa', last_name='Lumber', gender='Female', language='Tok Pisin')
# Record(ssn='317-28-1600', first_name='Rodrick', last_name='Abrahams', gender='Male', language='Assamese')
# Record(ssn='317-43-2055', first_name='Jocelyn', last_name='Gildroy', gender='Female', language='Punjabi')
# Record(ssn='318-58-5314', first_name='Stephan', last_name='Peatt', gender='Male', language='New Zealand Sign Language')
# Record(ssn='319-43-0465', first_name='Boothe', last_name='Vanin', gender='Male', language='West Frisian')
# Record(ssn='320-90-1419', first_name='Em', last_name='Darwood', gender='Male', language='Icelandic')
# Record(ssn='320-97-9147', first_name='Roch', last_name='Wahlberg', gender='Female', language='Thai')
# Record(ssn='323-28-6705', first_name='Christiano', last_name='Stoffler', gender='Male', language='Kyrgyz')
# Record(ssn='323-33-8689', first_name='Dulcinea', last_name='Lundberg', gender='Female', language='Dutch')
# Record(ssn='324-39-5230', first_name='Alexandrina', last_name='Dahlbom', gender='Female', language='Moldovan')
# Record(ssn='324-73-8895', first_name='Walliw', last_name='Alstead', gender='Female', language='Guarana')
# Record(ssn='324-75-6098', first_name='Rafael', last_name='Robinett', gender='Male', language='Portuguese')
# Record(ssn='326-64-9957', first_name='Jorgan', last_name='Renowden', gender='Male', language='Swati')
# Record(ssn='327-52-0546', first_name='Carlota', last_name='Hovey', gender='Female', language='English')
# Record(ssn='327-88-7554', first_name='Malynda', last_name='Kingerby', gender='Female', language='Swahili')
# Record(ssn='330-99-3055', first_name='Marinna', last_name='Dally', gender='Female', language='Azeri')
# Record(ssn='332-83-6591', first_name='Forrester', last_name='Cullabine', gender='Male', language='Dzongkha')
# Record(ssn='333-52-5097', first_name='Florentia', last_name='Espinazo', gender='Female', language='Tetum')
# Record(ssn='333-95-5025', first_name='Rebeca', last_name='Walesa', gender='Female', language='Zulu')
# Record(ssn='335-35-1520', first_name='Ervin', last_name='Hugues', gender='Male', language='Armenian')
# Record(ssn='336-48-2579', first_name='Renee', last_name='Crank', gender='Female', language='Armenian')
# Record(ssn='339-27-8046', first_name='Julita', last_name='Jouhan', gender='Female', language='Bosnian')
# Record(ssn='339-71-2687', first_name='Marlie', last_name='Corpe', gender='Female', language='Persian')
# Record(ssn='341-10-6840', first_name='Cyrille', last_name='Critchlow', gender='Male', language='Portuguese')
# Record(ssn='342-05-9057', first_name='Beatrix', last_name='Relton', gender='Female', language='Latvian')
# Record(ssn='342-55-0538', first_name='Hilliary', last_name='Suddards', gender='Female', language='Dzongkha')
# Record(ssn='342-90-9333', first_name='Geri', last_name='Yesinov', gender='Male', language='Norwegian')
# Record(ssn='343-20-8407', first_name='Bradford', last_name='Niemiec', gender='Male', language='Chinese')
# Record(ssn='343-81-3179', first_name='Reinhard', last_name='Bortolutti', gender='Male', language='Kannada')
# Record(ssn='345-74-2160', first_name='Camile', last_name='Pengelly', gender='Female', language='Lao')
# Record(ssn='347-09-3254', first_name='Dulciana', last_name='Hexum', gender='Female', language='Lao')
# Record(ssn='347-64-8652', first_name='Dusty', last_name='Morat', gender='Female', language='Japanese')
# Record(ssn='348-73-4312', first_name='Elberta', last_name='Howden', gender='Female', language='Khmer')
# Record(ssn='348-74-3224', first_name='Dorthy', last_name='Abreheart', gender='Female', language='Bosnian')
# Record(ssn='349-53-8864', first_name='Muffin', last_name='Lord', gender='Female', language='Georgian')
# Record(ssn='349-67-7502', first_name='Ari', last_name='Yitzhakov', gender='Male', language='Zulu')
# Record(ssn='350-20-9593', first_name='Eldridge', last_name='Crispin', gender='Male', language='Dutch')
# Record(ssn='350-80-4646', first_name='Harp', last_name='Du Plantier', gender='Male', language='Dutch')
# Record(ssn='351-73-2802', first_name='Cybill', last_name='Parnham', gender='Female', language='Latvian')
# Record(ssn='355-21-9711', first_name='Daryn', last_name='Battin', gender='Female', language='Georgian')
# Record(ssn='355-52-9767', first_name='Kacy', last_name='Offen', gender='Female', language='Kurdish')
# Record(ssn='355-96-7706', first_name='Lauritz', last_name='Lucock', gender='Male', language='Mongolian')
# Record(ssn='356-39-9199', first_name='Arney', last_name='Polglaze', gender='Male', language='Marathi')
# Record(ssn='357-37-6094', first_name='Chrisse', last_name='Kirton', gender='Male', language='Latvian')
# Record(ssn='358-84-7049', first_name='Emalee', last_name='McCleary', gender='Female', language='Thai')
# Record(ssn='360-69-6230', first_name='Grannie', last_name='Champ', gender='Male', language='Belarusian')
# Record(ssn='361-06-1530', first_name='Luis', last_name='Ashborne', gender='Male', language='Mongolian')
# Record(ssn='361-42-7068', first_name='Ashia', last_name='Ferran', gender='Female', language='West Frisian')
# Record(ssn='361-49-4597', first_name='Adan', last_name='Janssen', gender='Male', language='Swedish')
# Record(ssn='361-83-5004', first_name='Wilona', last_name='Sink', gender='Female', language='Sotho')
# Record(ssn='362-09-8563', first_name='Carri', last_name='Peterffy', gender='Female', language='Icelandic')
# Record(ssn='362-12-7902', first_name='Weber', last_name='Legrand', gender='Male', language='Swahili')
# Record(ssn='364-25-0166', first_name='Arnuad', last_name='Planque', gender='Male', language='Hindi')
# Record(ssn='364-65-2174', first_name='Bernarr', last_name='Wollard', gender='Male', language='Irish Gaelic')
# Record(ssn='366-61-0607', first_name='Bethena', last_name='Joicey', gender='Female', language='Haitian Creole')
# Record(ssn='367-22-8998', first_name='Blake', last_name='Mustin', gender='Female', language='Kyrgyz')
# Record(ssn='367-62-4426', first_name='Sigismondo', last_name='Lerohan', gender='Male', language='Georgian')
# Record(ssn='370-01-6977', first_name='Hugues', last_name='Jeffryes', gender='Male', language='Georgian')
# Record(ssn='370-24-5876', first_name='Sergei', last_name='Risby', gender='Male', language='Bulgarian')
# Record(ssn='370-72-6509', first_name='Wrennie', last_name='McCrorie', gender='Female', language='Papiamento')
# Record(ssn='371-28-5892', first_name='Malia', last_name='Hanse', gender='Female', language='Tsonga')
# Record(ssn='371-44-0582', first_name='Clemmy', last_name='Cogzell', gender='Male', language='Estonian')
# Record(ssn='371-62-3727', first_name='Cymbre', last_name='Chinnock', gender='Female', language='Dutch')
# Record(ssn='371-88-9249', first_name='Nealon', last_name='Oxtaby', gender='Male', language='German')
# Record(ssn='372-44-7487', first_name='Jolyn', last_name='Bertome', gender='Female', language='Catalan')
# Record(ssn='372-62-7057', first_name='Eleanora', last_name='Vazquez', gender='Female', language='Gujarati')
# Record(ssn='373-67-2734', first_name='Ileana', last_name='Luty', gender='Female', language='Italian')
# Record(ssn='374-47-0262', first_name='Bank', last_name='Evitts', gender='Male', language='Aymara')
# Record(ssn='378-08-0805', first_name='Carroll', last_name='Harty', gender='Female', language='Swedish')
# Record(ssn='378-60-2472', first_name='Eddie', last_name='Howieson', gender='Female', language='Albanian')
# Record(ssn='378-66-0449', first_name='Kelby', last_name='Wincer', gender='Male', language='Pashto')
# Record(ssn='378-79-0193', first_name='Kenny', last_name='Josefsen', gender='Male', language='Danish')
# Record(ssn='378-88-6805', first_name='Vittoria', last_name='Oldroyd', gender='Female', language='Moldovan')
# Record(ssn='379-07-8748', first_name='Dyanna', last_name='Noto', gender='Female', language='Polish')
# Record(ssn='380-33-9730', first_name='Katinka', last_name='Piet', gender='Female', language='Malay')
# Record(ssn='380-35-3854', first_name='Cathleen', last_name='Sizland', gender='Female', language='Bislama')
# Record(ssn='383-18-4058', first_name='Frederigo', last_name='Cooksey', gender='Male', language='Indonesian')
# Record(ssn='384-30-6793', first_name='Kipp', last_name='Burnyate', gender='Male', language='English')
# Record(ssn='384-94-2772', first_name='Ramsay', last_name='Dolbey', gender='Male', language='Tok Pisin')
# Record(ssn='385-30-1777', first_name='Aubrey', last_name='Wetherill', gender='Female', language='Tswana')
# Record(ssn='385-34-7828', first_name='Dori', last_name='Quogan', gender='Female', language='Afrikaans')
# Record(ssn='385-98-0431', first_name='Kassi', last_name='Rashleigh', gender='Female', language='Tswana')
# Record(ssn='386-15-7960', first_name='Steffie', last_name='Tedahl', gender='Female', language='Punjabi')
# Record(ssn='386-34-4088', first_name='Adamo', last_name='Wogden', gender='Male', language='Arabic')
# Record(ssn='386-68-9884', first_name='Francis', last_name='Foch', gender='Male', language='Dzongkha')
# Record(ssn='386-97-3523', first_name='Siusan', last_name='Durkin', gender='Female', language='Kurdish')
# Record(ssn='389-31-0910', first_name='Mac', last_name='Westrey', gender='Male', language='Armenian')
# Record(ssn='389-51-1424', first_name='Isadore', last_name='Orbine', gender='Male', language='Pashto')
# Record(ssn='389-84-8254', first_name='Chiquita', last_name='Jolliman', gender='Female', language='Marathi')
# Record(ssn='390-74-3062', first_name='Cara', last_name='Ingree', gender='Female', language='Indonesian')
# Record(ssn='391-14-9280', first_name='Faun', last_name='Chillistone', gender='Female', language='Montenegrin')
# Record(ssn='391-47-4578', first_name='Fiann', last_name='Fellman', gender='Female', language='Assamese')
# Record(ssn='391-73-2830', first_name='Padget', last_name='Manthorpe', gender='Male', language='Marathi')
# Record(ssn='393-22-6585', first_name='Reinold', last_name='Ellif', gender='Male', language='Nepali')
# Record(ssn='396-51-1559', first_name='Natasha', last_name='Dafter', gender='Female', language='Maori')
# Record(ssn='397-16-5372', first_name='Alonzo', last_name='Mc Mechan', gender='Male', language='Polish')
# Record(ssn='397-29-8349', first_name='Madelle', last_name='Mapledorum', gender='Female', language='Tok Pisin')
# Record(ssn='397-87-8282', first_name='Kyrstin', last_name='Waldock', gender='Female', language='Belarusian')
# Record(ssn='399-31-2815', first_name='Durward', last_name='Giamitti', gender='Male', language='Tok Pisin')
# Record(ssn='399-63-8810', first_name='Bobbee', last_name='Postians', gender='Female', language='Papiamento')
# Record(ssn='399-81-6133', first_name='Viv', last_name='Borsay', gender='Female', language='Chinese')
# Record(ssn='400-21-8654', first_name='Travus', last_name='Miranda', gender='Male', language='Kannada')
# Record(ssn='400-77-6007', first_name='Dannie', last_name='Shurmer', gender='Male', language='Tajik')
# Record(ssn='402-61-3479', first_name='Mariele', last_name='Meyrick', gender='Female', language='Telugu')
# Record(ssn='402-65-2055', first_name='Martie', last_name='Crawshaw', gender='Male', language='Marathi')
# Record(ssn='402-88-5570', first_name='Torry', last_name='Bossons', gender='Male', language='Chinese')
# Record(ssn='403-65-1535', first_name='Cathy', last_name='Gabe', gender='Female', language='Hiri Motu')
# Record(ssn='404-57-4023', first_name='Pattin', last_name='Jarmain', gender='Male', language='Hindi')
# Record(ssn='405-25-1422', first_name='Raquel', last_name='Dukelow', gender='Female', language='Gujarati')
# Record(ssn='406-15-5123', first_name='Janot', last_name='Pulhoster', gender='Female', language='Dari')
# Record(ssn='406-24-4867', first_name='Renaud', last_name='Fleetwood', gender='Male', language='Papiamento')
# Record(ssn='406-49-0634', first_name='Lolita', last_name='Dailey', gender='Female', language='Czech')
# Record(ssn='407-30-0910', first_name='Gerhard', last_name='Crielly', gender='Male', language='Bislama')
# Record(ssn='407-80-7367', first_name='Sigismundo', last_name='Pothbury', gender='Male', language='Latvian')
# Record(ssn='407-99-6159', first_name='Flynn', last_name='Jirasek', gender='Male', language='Afrikaans')
# Record(ssn='408-83-7943', first_name='Wallie', last_name='Klosterman', gender='Male', language='Hungarian')
# Record(ssn='408-98-3291', first_name='Karia', last_name='Riquet', gender='Female', language='Italian')
# Record(ssn='409-58-2034', first_name='Fiann', last_name='Corsar', gender='Female', language='Swahili')
# Record(ssn='409-90-8946', first_name='Doralia', last_name='Proughten', gender='Female', language='Estonian')
# Record(ssn='410-38-4237', first_name='Gibbie', last_name='Seamer', gender='Male', language='Tok Pisin')
# Record(ssn='410-76-5092', first_name='Spencer', last_name='Dallon', gender='Male', language='Swati')
# Record(ssn='411-21-4276', first_name='Mari', last_name='Livick', gender='Female', language='Pashto')
# Record(ssn='411-43-4217', first_name='Cull', last_name='Noddle', gender='Male', language='Spanish')
# Record(ssn='411-79-4655', first_name='Caterina', last_name='Coey', gender='Female', language='French')
# Record(ssn='412-50-9133', first_name='Dianemarie', last_name='Withey', gender='Female', language='Czech')
# Record(ssn='412-59-0452', first_name='Seamus', last_name='Petrusch', gender='Male', language='Spanish')
# Record(ssn='412-59-8022', first_name='Brenna', last_name='Follin', gender='Female', language='Gagauz')
# Record(ssn='412-79-8951', first_name='Giorgi', last_name='Sisnett', gender='Male', language='Tamil')
# Record(ssn='413-14-3928', first_name='Shaine', last_name='Liebrecht', gender='Male', language='Sotho')
# Record(ssn='413-56-5613', first_name='Anjanette', last_name='Carnock', gender='Female', language='Nepali')
# Record(ssn='415-42-0898', first_name='Karlik', last_name='Adlam', gender='Male', language='Mongolian')
# Record(ssn='415-74-2251', first_name='Pattin', last_name='Greson', gender='Male', language='Italian')
# Record(ssn='416-37-7763', first_name='Emelia', last_name='Hancell', gender='Female', language='German')
# Record(ssn='416-38-3607', first_name='Jerry', last_name='Christin', gender='Male', language='Hebrew')
# Record(ssn='416-80-6367', first_name='Myrna', last_name='Christoffe', gender='Female', language='Tok Pisin')
# Record(ssn='416-87-0469', first_name='Dannel', last_name='Whyffen', gender='Male', language='Estonian')
# Record(ssn='418-72-1888', first_name='Roddy', last_name='Worman', gender='Male', language='Bosnian')
# Record(ssn='418-99-6659', first_name='Grenville', last_name='Gulliver', gender='Male', language='Ndebele')
# Record(ssn='420-46-7789', first_name='Steffie', last_name='Britto', gender='Female', language='New Zealand Sign Language')
# Record(ssn='420-52-3813', first_name='Arnaldo', last_name='Balsdone', gender='Male', language='Zulu')
# Record(ssn='421-01-2511', first_name='Mikaela', last_name='Andrivot', gender='Female', language='English')
# Record(ssn='421-13-9794', first_name='Minne', last_name='Measey', gender='Female', language='Danish')
# Record(ssn='421-20-3448', first_name='Alie', last_name='Gerauld', gender='Female', language='Khmer')
# Record(ssn='421-88-7316', first_name='Cherie', last_name='Yeudall', gender='Female', language='Dutch')
# Record(ssn='422-67-4000', first_name='Corby', last_name='Boyington', gender='Male', language='Sotho')
# Record(ssn='423-62-1820', first_name='Ruddy', last_name='Ingerson', gender='Male', language='Maori')
# Record(ssn='423-88-4721', first_name='Trip', last_name='Postlewhite', gender='Male', language='Polish')
# Record(ssn='424-22-9138', first_name='Farand', last_name='Huggon', gender='Female', language='Indonesian')
# Record(ssn='424-91-0692', first_name='Jeanie', last_name='Titchard', gender='Female', language='Swati')
# Record(ssn='424-92-0863', first_name='Halley', last_name='Mendenhall', gender='Female', language='Thai')
# Record(ssn='426-09-8331', first_name='Enrico', last_name='Balentyne', gender='Male', language='Arabic')
# Record(ssn='426-33-4523', first_name='Bibbie', last_name='Lardge', gender='Female', language='Spanish')
# Record(ssn='426-52-3410', first_name='Deeyn', last_name='Feldberg', gender='Female', language='Lithuanian')
# Record(ssn='426-61-5374', first_name='Adolph', last_name='Effemy', gender='Male', language='Norwegian')
# Record(ssn='427-12-4625', first_name='Ethelin', last_name='Huck', gender='Female', language='Bosnian')
# Record(ssn='427-36-0095', first_name='Shandee', last_name='Hawthorne', gender='Female', language='Gujarati')
# Record(ssn='427-96-6355', first_name='Fidel', last_name='Gutierrez', gender='Male', language='Yiddish')
# Record(ssn='428-19-2946', first_name='Dionne', last_name='Bibb', gender='Female', language='Moldovan')
# Record(ssn='428-79-0781', first_name='Mame', last_name='Criag', gender='Female', language='Catalan')
# ...
# Record(ssn='773-21-9639', first_name='Brittney', last_name='Byart', gender='Female', language='Tok Pisin')
# Record(ssn='773-53-7438', first_name='Flo', last_name='Sirmond', gender='Female', language='Khmer')
# Record(ssn='773-82-1734', first_name='Maris', last_name='Currin', gender='Female', language='Armenian')
# Record(ssn='774-08-5376', first_name='Pam', last_name='Matterface', gender='Female', language='Swahili')
# Record(ssn='775-09-9949', first_name='Orlando', last_name='Gresley', gender='Male', language='Danish')
# Record(ssn='777-05-1491', first_name='Devora', last_name='Ashbridge', gender='Female', language='Somali')
# Record(ssn='777-68-2978', first_name='Mignon', last_name='Skottle', gender='Female', language='Northern Sotho')
# Record(ssn='777-94-4586', first_name='Siward', last_name='Blues', gender='Male', language='Thai')
# Record(ssn='778-74-8262', first_name='Sonia', last_name='Grishakin', gender='Female', language='Bulgarian')
# Record(ssn='779-59-1449', first_name='Gertrude', last_name='Ledamun', gender='Female', language='Hungarian')
# Record(ssn='780-69-8282', first_name='Sibeal', last_name='Dawney', gender='Female', language='Czech')
# Record(ssn='781-88-2076', first_name='Gelya', last_name='Stell', gender='Female', language='Czech')
# Record(ssn='782-46-9660', first_name='Malina', last_name='Julyan', gender='Female', language='Burmese')
# Record(ssn='782-60-6848', first_name='Jehu', last_name='Scholig', gender='Male', language='Polish')
# Record(ssn='783-22-9258', first_name='Modestine', last_name='Cuttings', gender='Female', language='Assamese')
# Record(ssn='784-88-0730', first_name='Baxie', last_name='Judd', gender='Male', language='Maltese')
# Record(ssn='785-14-5978', first_name='Trista', last_name='Watkinson', gender='Female', language='Moldovan')
# Record(ssn='786-56-3561', first_name='Wait', last_name='Boyda', gender='Male', language='Norwegian')
# Record(ssn='786-63-6223', first_name='Adham', last_name='Toope', gender='Male', language='Belarusian')
# Record(ssn='787-05-9008', first_name='Ricki', last_name='Jurges', gender='Female', language='Arabic')
# Record(ssn='787-09-5697', first_name='Chelsea', last_name='Pashby', gender='Female', language='Northern Sotho')
# Record(ssn='787-10-7877', first_name='Torrence', last_name='Tapping', gender='Male', language='Hiri Motu')
# Record(ssn='788-15-2625', first_name='Drusilla', last_name='Bannester', gender='Female', language='Gujarati')
# Record(ssn='789-70-1821', first_name='Denni', last_name='De Biasio', gender='Female', language='Azeri')
# Record(ssn='790-04-1283', first_name='Christyna', last_name='Morrissey', gender='Female', language='Quechua')
# Record(ssn='792-71-8046', first_name='Carly', last_name='Hazley', gender='Female', language='Guarana')
# Record(ssn='794-24-3802', first_name='Esther', last_name='Sayton', gender='Female', language='Somali')
# Record(ssn='795-56-6486', first_name='Stevena', last_name='Vatcher', gender='Female', language='Gagauz')
# Record(ssn='795-77-5263', first_name='Burty', last_name='Frosdick', gender='Male', language='Marathi')
# Record(ssn='797-05-2289', first_name='Fanchon', last_name='Petrushanko', gender='Female', language='Finnish')
# Record(ssn='797-25-9814', first_name='Aleksandr', last_name='Swalwell', gender='Male', language='Pashto')
# Record(ssn='797-65-2382', first_name='Marianne', last_name='Huccaby', gender='Female', language='Swedish')
# Record(ssn='797-87-7992', first_name='Lonna', last_name='Plumridge', gender='Female', language='Armenian')
# Record(ssn='798-34-1082', first_name='Henka', last_name='Synder', gender='Female', language='Italian')
# Record(ssn='798-65-5644', first_name='Irita', last_name='Heady', gender='Female', language='Montenegrin')
# Record(ssn='800-06-9721', first_name='Carter', last_name='Waldron', gender='Male', language='Estonian')
# Record(ssn='801-08-8313', first_name='Aida', last_name='Whitemarsh', gender='Female', language='Chinese')
# Record(ssn='801-92-6460', first_name='Levi', last_name='Downgate', gender='Male', language='Belarusian')
# Record(ssn='801-99-2773', first_name='Justinian', last_name='Carlesso', gender='Male', language='Japanese')
# Record(ssn='804-46-0617', first_name='Geneva', last_name='Crinion', gender='Female', language='Hungarian')
# Record(ssn='807-13-5922', first_name='Vivi', last_name='Edinboro', gender='Female', language='Sotho')
# Record(ssn='807-24-6202', first_name='Lanette', last_name='Elvins', gender='Female', language='Hiri Motu')
# Record(ssn='807-25-6136', first_name='Sammy', last_name='Linnard', gender='Female', language='Dutch')
# Record(ssn='807-35-8936', first_name='Georgi', last_name='Widd', gender='Male', language='Afrikaans')
# Record(ssn='807-50-8539', first_name='Jaquith', last_name='Erdes', gender='Female', language='Dhivehi')
# Record(ssn='807-60-5615', first_name='Michale', last_name='Druery', gender='Male', language='Dhivehi')
# Record(ssn='808-55-8658', first_name='Ursulina', last_name='Kunze', gender='Female', language='Chinese')
# Record(ssn='808-80-2542', first_name='Gustaf', last_name='Hullot', gender='Male', language='Persian')
# Record(ssn='811-65-2750', first_name='Minetta', last_name='Dusting', gender='Female', language='Spanish')
# Record(ssn='812-11-9403', first_name='Carmina', last_name='Turnell', gender='Female', language='West Frisian')
# Record(ssn='813-42-4142', first_name='Killy', last_name='Threadgould', gender='Male', language='Polish')
# Record(ssn='813-47-5215', first_name='Willi', last_name='Collet', gender='Male', language='Gujarati')
# Record(ssn='815-83-0300', first_name='Romeo', last_name='Rayworth', gender='Male', language='Thai')
# Record(ssn='816-31-3858', first_name='Elvera', last_name='Walmsley', gender='Female', language='Montenegrin')
# Record(ssn='816-47-4782', first_name='Wilmer', last_name='Maides', gender='Male', language='Aymara')
# Record(ssn='816-90-2049', first_name='Berry', last_name='Delagnes', gender='Female', language='Bengali')
# Record(ssn='817-04-1950', first_name='Fletcher', last_name='McGrouther', gender='Male', language='Albanian')
# Record(ssn='817-25-7437', first_name='Randall', last_name='Fibbitts', gender='Male', language='Yiddish')
# Record(ssn='817-80-8930', first_name='Lib', last_name='Skein', gender='Female', language='Arabic')
# Record(ssn='818-61-0770', first_name='Stanly', last_name='Casseldine', gender='Male', language='Belarusian')
# Record(ssn='819-52-5886', first_name='Paulette', last_name='McAree', gender='Female', language='Arabic')
# Record(ssn='819-64-1414', first_name='Malynda', last_name='Hundall', gender='Female', language='Filipino')
# Record(ssn='820-96-1105', first_name='Andy', last_name='Sayce', gender='Female', language='Pashto')
# Record(ssn='822-05-9037', first_name='Meggi', last_name='Mapes', gender='Female', language='Moldovan')
# Record(ssn='822-30-4861', first_name='Phyllis', last_name='Cronk', gender='Female', language='Fijian')
# Record(ssn='823-27-0762', first_name='Marten', last_name='McCord', gender='Male', language='Indonesian')
# Record(ssn='823-75-5753', first_name='Thibaut', last_name='Van Schafflaer', gender='Male', language='Chinese')
# Record(ssn='824-89-4169', first_name='Tamqrah', last_name='Goroni', gender='Female', language='Swedish')
# Record(ssn='826-97-8029', first_name='Llewellyn', last_name='Shimwell', gender='Male', language='Belarusian')
# Record(ssn='827-62-4599', first_name='Phyllys', last_name='Akast', gender='Female', language='Armenian')
# Record(ssn='830-23-1573', first_name='Carine', last_name='Abramin', gender='Female', language='Bislama')
# Record(ssn='831-44-3286', first_name='Leesa', last_name='Finci', gender='Female', language='Nepali')
# Record(ssn='833-01-1428', first_name='Ashlan', last_name='Zannotti', gender='Female', language='Finnish')
# Record(ssn='835-54-3785', first_name='Nathaniel', last_name='Wegman', gender='Male', language='Azeri')
# Record(ssn='836-40-1837', first_name='Brocky', last_name='Kewzick', gender='Male', language='Armenian')
# Record(ssn='836-99-3309', first_name='Cobby', last_name='Mutter', gender='Male', language='Georgian')
# Record(ssn='837-76-5619', first_name='Alleyn', last_name='Parade', gender='Male', language='Croatian')
# Record(ssn='838-69-1351', first_name='Alwin', last_name='Hazzard', gender='Male', language='Kannada')
# Record(ssn='840-41-7929', first_name='Sherlock', last_name='Pinshon', gender='Male', language='Khmer')
# Record(ssn='841-64-8517', first_name='Hugues', last_name='Kenealy', gender='Male', language='Korean')
# Record(ssn='842-90-7557', first_name='Brit', last_name='Weall', gender='Female', language='West Frisian')
# Record(ssn='844-15-4668', first_name='Eleonora', last_name='Delete', gender='Female', language='Hiri Motu')
# Record(ssn='844-50-7305', first_name='Merralee', last_name='Orae', gender='Female', language='Macedonian')
# Record(ssn='846-07-1407', first_name='Tobias', last_name='Blakelock', gender='Male', language='German')
# Record(ssn='846-09-9851', first_name='Shani', last_name='Penrose', gender='Female', language='New Zealand Sign Language')
# Record(ssn='846-59-9961', first_name='Saleem', last_name='Osmant', gender='Male', language='Croatian')
# Record(ssn='847-34-4817', first_name='Orazio', last_name='Coners', gender='Male', language='Yiddish')
# Record(ssn='847-61-7656', first_name='Brit', last_name='Lodovichi', gender='Male', language='Bislama')
# Record(ssn='848-58-3386', first_name='Julianne', last_name='Lygo', gender='Female', language='Japanese')
# Record(ssn='848-74-2886', first_name='Helyn', last_name='Witheford', gender='Female', language='Bislama')
# Record(ssn='848-76-8808', first_name='Durward', last_name='Nuscha', gender='Male', language='Nepali')
# Record(ssn='849-31-1551', first_name='Lisabeth', last_name='Mattessen', gender='Female', language='German')
# Record(ssn='849-64-6624', first_name='Hallie', last_name='Proschke', gender='Female', language='Fijian')
# Record(ssn='849-98-2973', first_name='Hurley', last_name='Newart', gender='Male', language='Hindi')
# Record(ssn='851-94-2162', first_name='Rodi', last_name='Mulrenan', gender='Female', language='Catalan')
# Record(ssn='852-15-7707', first_name='Mario', last_name='Lelande', gender='Male', language='Nepali')
# Record(ssn='853-11-8953', first_name='Brice', last_name='Kyd', gender='Male', language='Dari')
# Record(ssn='853-47-3648', first_name='Olag', last_name='Belhome', gender='Male', language='Maltese')
# Record(ssn='854-68-7635', first_name='Eyde', last_name='McCunn', gender='Female', language='Moldovan')
# Record(ssn='854-71-2983', first_name='Rikki', last_name='Loveland', gender='Male', language='Dutch')
# Record(ssn='854-79-5334', first_name='Bevan', last_name='Kolczynski', gender='Male', language='Swahili')
# Record(ssn='856-18-3980', first_name='Neale', last_name='Sesser', gender='Male', language='Maltese')
# Record(ssn='856-27-9112', first_name='Virgilio', last_name='Kirrage', gender='Male', language='Pashto')
# Record(ssn='856-67-4080', first_name='Aggy', last_name='Cobley', gender='Female', language='Dhivehi')
# Record(ssn='857-37-5902', first_name='Jenni', last_name='Swinyard', gender='Female', language='Hindi')
# Record(ssn='858-03-7735', first_name='Allayne', last_name='Wardingley', gender='Male', language='Kazakh')
# Record(ssn='858-27-9190', first_name='Yuri', last_name='Sixsmith', gender='Male', language='Norwegian')
# Record(ssn='860-67-0256', first_name='Bendicty', last_name='Lindgren', gender='Male', language='Tajik')
# Record(ssn='860-89-2570', first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish')
# Record(ssn='861-50-6716', first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian')
# Record(ssn='862-20-0653', first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish')
# Record(ssn='864-22-9364', first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian')
# Record(ssn='864-91-7489', first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama')
# Record(ssn='866-18-1440', first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento')
# Record(ssn='866-53-0625', first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian')
# Record(ssn='867-11-6007', first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam')
# Record(ssn='867-13-6844', first_name='Clo', last_name='Skacel', gender='Female', language='Armenian')
# Record(ssn='867-88-2360', first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha')
# Record(ssn='868-32-1805', first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian')
# Record(ssn='870-12-6609', first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana')
# Record(ssn='870-93-1121', first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew')
# Record(ssn='871-99-3191', first_name='Susann', last_name='Walrond', gender='Female', language='Amharic')
# Record(ssn='872-18-9267', first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese')
# Record(ssn='872-49-1288', first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish')
# Record(ssn='873-36-4733', first_name='Locke', last_name='Staries', gender='Male', language='Moldovan')
# Record(ssn='875-18-9454', first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu')
# Record(ssn='875-75-0495', first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish')
# Record(ssn='878-12-8265', first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi')
# Record(ssn='880-22-4449', first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri')
# Record(ssn='881-19-5974', first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho')
# Record(ssn='881-88-7308', first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga')
# Record(ssn='881-95-7180', first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian')
# Record(ssn='882-49-5290', first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian')
# Record(ssn='884-61-1852', first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian')
# Record(ssn='887-41-7878', first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil')
# Record(ssn='887-83-9002', first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin')
# Record(ssn='888-50-7008', first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha')
# Record(ssn='888-53-7684', first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian')
# Record(ssn='888-82-4928', first_name='Billye', last_name='Legat', gender='Female', language='Icelandic')
# Record(ssn='890-28-9962', first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua')
# Record(ssn='893-12-0901', first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya')
# Record(ssn='893-17-7318', first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz')
# Record(ssn='894-81-0628', first_name='Ree', last_name='Mordue', gender='Female', language='Tswana')
# Record(ssn='895-26-1658', first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic')
# Record(ssn='895-26-5515', first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho')
# Record(ssn='897-76-7070', first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali')
# Record(ssn='898-03-3165', first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic')
# Record(ssn='898-86-8860', first_name='Hershel', last_name='Few', gender='Male', language='Gagauz')
# Record(ssn='899-09-1766', first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino')
# Record(ssn='899-39-7179', first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek')
# Record(ssn='899-39-7378', first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian')
# Record(ssn='899-47-6116', first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum')

# %%
# Goal 2

# %%
from contextlib import contextmanager

# %%
@contextmanager
def parsed_data(f_name):
    f = open(f_name)
    try:
        dialect = csv.Sniffer().sniff(f.read(1024))
        f.seek(0)
        csvreader = csv.reader(f, dialect)
        fieldnames = ['_'.join(fieldname.lower().split()) for fieldname in next(csvreader)]
        Record = namedtuple('Record', fieldnames, rename=True)
        yield (Record(*row) for row in csvreader)
    finally:
        f.close()

# %%
f_names = 'cars.csv', 'personal_info.csv'
for f_name in f_names:
    with parsed_data(f_name) as data:
        for row in islice(data, 5):
            print(row)
    print('-------------------')
# Out:
# Record(car='Chevrolet Chevelle Malibu', mpg='18.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='3504.', acceleration='12.0', model='70', origin='US')
# Record(car='Buick Skylark 320', mpg='15.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='3693.', acceleration='11.5', model='70', origin='US')
# Record(car='Plymouth Satellite', mpg='18.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3436.', acceleration='11.0', model='70', origin='US')
# Record(car='AMC Rebel SST', mpg='16.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3433.', acceleration='12.0', model='70', origin='US')
# Record(car='Ford Torino', mpg='17.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3449.', acceleration='10.5', model='70', origin='US')
# -------------------
# Record(ssn='100-53-9824', first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic')
# Record(ssn='101-71-4702', first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao')
# Record(ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish')
# Record(ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi')
# Record(ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans')
# -------------------

# %%
for f_name in f_names:
    with parsed_data(f_name) as data:
        for row in data:
            print(row)
    print('-------------------')
# Out:
# Record(car='Chevrolet Chevelle Malibu', mpg='18.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='3504.', acceleration='12.0', model='70', origin='US')
# Record(car='Buick Skylark 320', mpg='15.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='3693.', acceleration='11.5', model='70', origin='US')
# Record(car='Plymouth Satellite', mpg='18.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3436.', acceleration='11.0', model='70', origin='US')
# Record(car='AMC Rebel SST', mpg='16.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3433.', acceleration='12.0', model='70', origin='US')
# Record(car='Ford Torino', mpg='17.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3449.', acceleration='10.5', model='70', origin='US')
# Record(car='Ford Galaxie 500', mpg='15.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4341.', acceleration='10.0', model='70', origin='US')
# Record(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='454.0', horsepower='220.0', weight='4354.', acceleration='9.0', model='70', origin='US')
# Record(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4312.', acceleration='8.5', model='70', origin='US')
# Record(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4425.', acceleration='10.0', model='70', origin='US')
# Record(car='AMC Ambassador DPL', mpg='15.0', cylinders='8', displacement='390.0', horsepower='190.0', weight='3850.', acceleration='8.5', model='70', origin='US')
# Record(car='Citroen DS-21 Pallas', mpg='0', cylinders='4', displacement='133.0', horsepower='115.0', weight='3090.', acceleration='17.5', model='70', origin='Europe')
# Record(car='Chevrolet Chevelle Concours (sw)', mpg='0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4142.', acceleration='11.5', model='70', origin='US')
# Record(car='Ford Torino (sw)', mpg='0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4034.', acceleration='11.0', model='70', origin='US')
# Record(car='Plymouth Satellite (sw)', mpg='0', cylinders='8', displacement='383.0', horsepower='175.0', weight='4166.', acceleration='10.5', model='70', origin='US')
# Record(car='AMC Rebel SST (sw)', mpg='0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3850.', acceleration='11.0', model='70', origin='US')
# Record(car='Dodge Challenger SE', mpg='15.0', cylinders='8', displacement='383.0', horsepower='170.0', weight='3563.', acceleration='10.0', model='70', origin='US')
# Record(car="Plymouth 'Cuda 340", mpg='14.0', cylinders='8', displacement='340.0', horsepower='160.0', weight='3609.', acceleration='8.0', model='70', origin='US')
# Record(car='Ford Mustang Boss 302', mpg='0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3353.', acceleration='8.0', model='70', origin='US')
# Record(car='Chevrolet Monte Carlo', mpg='15.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='3761.', acceleration='9.5', model='70', origin='US')
# Record(car='Buick Estate Wagon (sw)', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='3086.', acceleration='10.0', model='70', origin='US')
# Record(car='Toyota Corolla Mark ii', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2372.', acceleration='15.0', model='70', origin='Japan')
# Record(car='Plymouth Duster', mpg='22.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2833.', acceleration='15.5', model='70', origin='US')
# Record(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='199.0', horsepower='97.00', weight='2774.', acceleration='15.5', model='70', origin='US')
# Record(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='85.00', weight='2587.', acceleration='16.0', model='70', origin='US')
# Record(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='70', origin='Japan')
# Record(car='Volkswagen 1131 Deluxe Sedan', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1835.', acceleration='20.5', model='70', origin='Europe')
# Record(car='Peugeot 504', mpg='25.0', cylinders='4', displacement='110.0', horsepower='87.00', weight='2672.', acceleration='17.5', model='70', origin='Europe')
# Record(car='Audi 100 LS', mpg='24.0', cylinders='4', displacement='107.0', horsepower='90.00', weight='2430.', acceleration='14.5', model='70', origin='Europe')
# Record(car='Saab 99e', mpg='25.0', cylinders='4', displacement='104.0', horsepower='95.00', weight='2375.', acceleration='17.5', model='70', origin='Europe')
# Record(car='BMW 2002', mpg='26.0', cylinders='4', displacement='121.0', horsepower='113.0', weight='2234.', acceleration='12.5', model='70', origin='Europe')
# Record(car='AMC Gremlin', mpg='21.0', cylinders='6', displacement='199.0', horsepower='90.00', weight='2648.', acceleration='15.0', model='70', origin='US')
# Record(car='Ford F250', mpg='10.0', cylinders='8', displacement='360.0', horsepower='215.0', weight='4615.', acceleration='14.0', model='70', origin='US')
# Record(car='Chevy C20', mpg='10.0', cylinders='8', displacement='307.0', horsepower='200.0', weight='4376.', acceleration='15.0', model='70', origin='US')
# Record(car='Dodge D200', mpg='11.0', cylinders='8', displacement='318.0', horsepower='210.0', weight='4382.', acceleration='13.5', model='70', origin='US')
# Record(car='Hi 1200D', mpg='9.0', cylinders='8', displacement='304.0', horsepower='193.0', weight='4732.', acceleration='18.5', model='70', origin='US')
# Record(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='71', origin='Japan')
# Record(car='Chevrolet Vega 2300', mpg='28.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2264.', acceleration='15.5', model='71', origin='US')
# Record(car='Toyota Corolla', mpg='25.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2228.', acceleration='14.0', model='71', origin='Japan')
# Record(car='Ford Pinto', mpg='25.0', cylinders='4', displacement='98.00', horsepower='0', weight='2046.', acceleration='19.0', model='71', origin='US')
# Record(car='Volkswagen Super Beetle 117', mpg='0', cylinders='4', displacement='97.00', horsepower='48.00', weight='1978.', acceleration='20.0', model='71', origin='Europe')
# Record(car='AMC Gremlin', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2634.', acceleration='13.0', model='71', origin='US')
# Record(car='Plymouth Satellite Custom', mpg='16.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3439.', acceleration='15.5', model='71', origin='US')
# Record(car='Chevrolet Chevelle Malibu', mpg='17.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3329.', acceleration='15.5', model='71', origin='US')
# Record(car='Ford Torino 500', mpg='19.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3302.', acceleration='15.5', model='71', origin='US')
# Record(car='AMC Matador', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='3288.', acceleration='15.5', model='71', origin='US')
# Record(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4209.', acceleration='12.0', model='71', origin='US')
# Record(car='Pontiac Catalina Brougham', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4464.', acceleration='11.5', model='71', origin='US')
# Record(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4154.', acceleration='13.5', model='71', origin='US')
# Record(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4096.', acceleration='13.0', model='71', origin='US')
# Record(car='Dodge Monaco (sw)', mpg='12.0', cylinders='8', displacement='383.0', horsepower='180.0', weight='4955.', acceleration='11.5', model='71', origin='US')
# Record(car='Ford Country Squire (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4746.', acceleration='12.0', model='71', origin='US')
# Record(car='Pontiac Safari (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='5140.', acceleration='12.0', model='71', origin='US')
# Record(car='AMC Hornet Sportabout (sw)', mpg='18.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='2962.', acceleration='13.5', model='71', origin='US')
# Record(car='Chevrolet Vega (sw)', mpg='22.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2408.', acceleration='19.0', model='71', origin='US')
# Record(car='Pontiac Firebird', mpg='19.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3282.', acceleration='15.0', model='71', origin='US')
# Record(car='Ford Mustang', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3139.', acceleration='14.5', model='71', origin='US')
# Record(car='Mercury Capri 2000', mpg='23.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2220.', acceleration='14.0', model='71', origin='US')
# Record(car='Opel 1900', mpg='28.0', cylinders='4', displacement='116.0', horsepower='90.00', weight='2123.', acceleration='14.0', model='71', origin='Europe')
# Record(car='Peugeot 304', mpg='30.0', cylinders='4', displacement='79.00', horsepower='70.00', weight='2074.', acceleration='19.5', model='71', origin='Europe')
# Record(car='Fiat 124B', mpg='30.0', cylinders='4', displacement='88.00', horsepower='76.00', weight='2065.', acceleration='14.5', model='71', origin='Europe')
# Record(car='Toyota Corolla 1200', mpg='31.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1773.', acceleration='19.0', model='71', origin='Japan')
# Record(car='Datsun 1200', mpg='35.0', cylinders='4', displacement='72.00', horsepower='69.00', weight='1613.', acceleration='18.0', model='71', origin='Japan')
# Record(car='Volkswagen Model 111', mpg='27.0', cylinders='4', displacement='97.00', horsepower='60.00', weight='1834.', acceleration='19.0', model='71', origin='Europe')
# Record(car='Plymouth Cricket', mpg='26.0', cylinders='4', displacement='91.00', horsepower='70.00', weight='1955.', acceleration='20.5', model='71', origin='US')
# Record(car='Toyota Corolla Hardtop', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2278.', acceleration='15.5', model='72', origin='Japan')
# Record(car='Dodge Colt Hardtop', mpg='25.0', cylinders='4', displacement='97.50', horsepower='80.00', weight='2126.', acceleration='17.0', model='72', origin='US')
# Record(car='Volkswagen Type 3', mpg='23.0', cylinders='4', displacement='97.00', horsepower='54.00', weight='2254.', acceleration='23.5', model='72', origin='Europe')
# Record(car='Chevrolet Vega', mpg='20.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2408.', acceleration='19.5', model='72', origin='US')
# Record(car='Ford Pinto Runabout', mpg='21.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2226.', acceleration='16.5', model='72', origin='US')
# Record(car='Chevrolet Impala', mpg='13.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4274.', acceleration='12.0', model='72', origin='US')
# Record(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4385.', acceleration='12.0', model='72', origin='US')
# Record(car='Plymouth Fury III', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4135.', acceleration='13.5', model='72', origin='US')
# Record(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4129.', acceleration='13.0', model='72', origin='US')
# Record(car='AMC Ambassador SST', mpg='17.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='72', origin='US')
# Record(car='Mercury Marquis', mpg='11.0', cylinders='8', displacement='429.0', horsepower='208.0', weight='4633.', acceleration='11.0', model='72', origin='US')
# Record(car='Buick LeSabre Custom', mpg='13.0', cylinders='8', displacement='350.0', horsepower='155.0', weight='4502.', acceleration='13.5', model='72', origin='US')
# Record(car='Oldsmobile Delta 88 Royale', mpg='12.0', cylinders='8', displacement='350.0', horsepower='160.0', weight='4456.', acceleration='13.5', model='72', origin='US')
# Record(car='Chrysler Newport Royal', mpg='13.0', cylinders='8', displacement='400.0', horsepower='190.0', weight='4422.', acceleration='12.5', model='72', origin='US')
# Record(car='Mazda RX2 Coupe', mpg='19.0', cylinders='3', displacement='70.00', horsepower='97.00', weight='2330.', acceleration='13.5', model='72', origin='Japan')
# Record(car='AMC Matador (sw)', mpg='15.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3892.', acceleration='12.5', model='72', origin='US')
# Record(car='Chevrolet Chevelle Concours (sw)', mpg='13.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='4098.', acceleration='14.0', model='72', origin='US')
# Record(car='Ford Gran Torino (sw)', mpg='13.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4294.', acceleration='16.0', model='72', origin='US')
# Record(car='Plymouth Satellite Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4077.', acceleration='14.0', model='72', origin='US')
# Record(car='Volvo 145e (sw)', mpg='18.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2933.', acceleration='14.5', model='72', origin='Europe')
# Record(car='Volkswagen 411 (sw)', mpg='22.0', cylinders='4', displacement='121.0', horsepower='76.00', weight='2511.', acceleration='18.0', model='72', origin='Europe')
# Record(car='Peugeot 504 (sw)', mpg='21.0', cylinders='4', displacement='120.0', horsepower='87.00', weight='2979.', acceleration='19.5', model='72', origin='Europe')
# Record(car='Renault 12 (sw)', mpg='26.0', cylinders='4', displacement='96.00', horsepower='69.00', weight='2189.', acceleration='18.0', model='72', origin='Europe')
# Record(car='Ford Pinto (sw)', mpg='22.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2395.', acceleration='16.0', model='72', origin='US')
# Record(car='Datsun 510 (sw)', mpg='28.0', cylinders='4', displacement='97.00', horsepower='92.00', weight='2288.', acceleration='17.0', model='72', origin='Japan')
# Record(car='Toyota Corolla Mark II (sw)', mpg='23.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2506.', acceleration='14.5', model='72', origin='Japan')
# Record(car='Dodge Colt (sw)', mpg='28.0', cylinders='4', displacement='98.00', horsepower='80.00', weight='2164.', acceleration='15.0', model='72', origin='US')
# Record(car='Toyota Corolla 1600 (sw)', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2100.', acceleration='16.5', model='72', origin='Japan')
# Record(car='Buick Century 350', mpg='13.0', cylinders='8', displacement='350.0', horsepower='175.0', weight='4100.', acceleration='13.0', model='73', origin='US')
# Record(car='AMC Matador', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='73', origin='US')
# Record(car='Chevrolet Malibu', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='3988.', acceleration='13.0', model='73', origin='US')
# Record(car='Ford Gran Torino', mpg='14.0', cylinders='8', displacement='302.0', horsepower='137.0', weight='4042.', acceleration='14.5', model='73', origin='US')
# Record(car='Dodge Coronet Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3777.', acceleration='12.5', model='73', origin='US')
# Record(car='Mercury Marquis Brougham', mpg='12.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4952.', acceleration='11.5', model='73', origin='US')
# Record(car='Chevrolet Caprice Classic', mpg='13.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4464.', acceleration='12.0', model='73', origin='US')
# Record(car='Ford LTD', mpg='13.0', cylinders='8', displacement='351.0', horsepower='158.0', weight='4363.', acceleration='13.0', model='73', origin='US')
# Record(car='Plymouth Fury Gran Sedan', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4237.', acceleration='14.5', model='73', origin='US')
# Record(car='Chrysler New Yorker Brougham', mpg='13.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4735.', acceleration='11.0', model='73', origin='US')
# Record(car='Buick Electra 225 Custom', mpg='12.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4951.', acceleration='11.0', model='73', origin='US')
# Record(car='AMC Ambassador Brougham', mpg='13.0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3821.', acceleration='11.0', model='73', origin='US')
# Record(car='Plymouth Valiant', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3121.', acceleration='16.5', model='73', origin='US')
# Record(car='Chevrolet Nova Custom', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3278.', acceleration='18.0', model='73', origin='US')
# Record(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2945.', acceleration='16.0', model='73', origin='US')
# Record(car='Ford Maverick', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3021.', acceleration='16.5', model='73', origin='US')
# Record(car='Plymouth Duster', mpg='23.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2904.', acceleration='16.0', model='73', origin='US')
# Record(car='Volkswagen Super Beetle', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1950.', acceleration='21.0', model='73', origin='Europe')
# Record(car='Chevrolet Impala', mpg='11.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4997.', acceleration='14.0', model='73', origin='US')
# Record(car='Ford Country', mpg='12.0', cylinders='8', displacement='400.0', horsepower='167.0', weight='4906.', acceleration='12.5', model='73', origin='US')
# Record(car='Plymouth Custom Suburb', mpg='13.0', cylinders='8', displacement='360.0', horsepower='170.0', weight='4654.', acceleration='13.0', model='73', origin='US')
# Record(car='Oldsmobile Vista Cruiser', mpg='12.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='4499.', acceleration='12.5', model='73', origin='US')
# Record(car='AMC Gremlin', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2789.', acceleration='15.0', model='73', origin='US')
# Record(car='Toyota Camry', mpg='20.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2279.', acceleration='19.0', model='73', origin='Japan')
# Record(car='Chevrolet Vega', mpg='21.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2401.', acceleration='19.5', model='73', origin='US')
# Record(car='Datsun 610', mpg='22.0', cylinders='4', displacement='108.0', horsepower='94.00', weight='2379.', acceleration='16.5', model='73', origin='Japan')
# Record(car='Mazda RX3', mpg='18.0', cylinders='3', displacement='70.00', horsepower='90.00', weight='2124.', acceleration='13.5', model='73', origin='Japan')
# Record(car='Ford Pinto', mpg='19.0', cylinders='4', displacement='122.0', horsepower='85.00', weight='2310.', acceleration='18.5', model='73', origin='US')
# Record(car='Mercury Capri v6', mpg='21.0', cylinders='6', displacement='155.0', horsepower='107.0', weight='2472.', acceleration='14.0', model='73', origin='US')
# Record(car='Fiat 124 Sport Coupe', mpg='26.0', cylinders='4', displacement='98.00', horsepower='90.00', weight='2265.', acceleration='15.5', model='73', origin='Europe')
# Record(car='Chevrolet Monte Carlo S', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4082.', acceleration='13.0', model='73', origin='US')
# Record(car='Pontiac Grand Prix', mpg='16.0', cylinders='8', displacement='400.0', horsepower='230.0', weight='4278.', acceleration='9.50', model='73', origin='US')
# Record(car='Fiat 128', mpg='29.0', cylinders='4', displacement='68.00', horsepower='49.00', weight='1867.', acceleration='19.5', model='73', origin='Europe')
# Record(car='Opel Manta', mpg='24.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2158.', acceleration='15.5', model='73', origin='Europe')
# Record(car='Audi 100LS', mpg='20.0', cylinders='4', displacement='114.0', horsepower='91.00', weight='2582.', acceleration='14.0', model='73', origin='Europe')
# Record(car='Volvo 144ea', mpg='19.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2868.', acceleration='15.5', model='73', origin='Europe')
# Record(car='Dodge Dart Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3399.', acceleration='11.0', model='73', origin='US')
# Record(car='Saab 99le', mpg='24.0', cylinders='4', displacement='121.0', horsepower='110.0', weight='2660.', acceleration='14.0', model='73', origin='Europe')
# Record(car='Toyota Mark II', mpg='20.0', cylinders='6', displacement='156.0', horsepower='122.0', weight='2807.', acceleration='13.5', model='73', origin='Japan')
# Record(car='Oldsmobile Omega', mpg='11.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='3664.', acceleration='11.0', model='73', origin='US')
# Record(car='Plymouth Duster', mpg='20.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='3102.', acceleration='16.5', model='74', origin='US')
# Record(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='0', weight='2875.', acceleration='17.0', model='74', origin='US')
# Record(car='AMC Hornet', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2901.', acceleration='16.0', model='74', origin='US')
# Record(car='Chevrolet Nova', mpg='15.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3336.', acceleration='17.0', model='74', origin='US')
# Record(car='Datsun B210', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1950.', acceleration='19.0', model='74', origin='Japan')
# Record(car='Ford Pinto', mpg='26.0', cylinders='4', displacement='122.0', horsepower='80.00', weight='2451.', acceleration='16.5', model='74', origin='US')
# Record(car='Toyota Corolla 1200', mpg='32.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1836.', acceleration='21.0', model='74', origin='Japan')
# Record(car='Chevrolet Vega', mpg='25.0', cylinders='4', displacement='140.0', horsepower='75.00', weight='2542.', acceleration='17.0', model='74', origin='US')
# Record(car='Chevrolet Chevelle Malibu Classic', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3781.', acceleration='17.0', model='74', origin='US')
# Record(car='AMC Matador', mpg='16.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3632.', acceleration='18.0', model='74', origin='US')
# Record(car='Plymouth Satellite Sebring', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3613.', acceleration='16.5', model='74', origin='US')
# Record(car='Ford Gran Torino', mpg='16.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4141.', acceleration='14.0', model='74', origin='US')
# Record(car='Buick Century Luxus (sw)', mpg='13.0', cylinders='8', displacement='350.0', horsepower='150.0', weight='4699.', acceleration='14.5', model='74', origin='US')
# Record(car='Dodge Coronet Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4457.', acceleration='13.5', model='74', origin='US')
# Record(car='Ford Gran Torino (sw)', mpg='14.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4638.', acceleration='16.0', model='74', origin='US')
# Record(car='AMC Matador (sw)', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='4257.', acceleration='15.5', model='74', origin='US')
# Record(car='Audi Fox', mpg='29.0', cylinders='4', displacement='98.00', horsepower='83.00', weight='2219.', acceleration='16.5', model='74', origin='Europe')
# Record(car='Volkswagen Dasher', mpg='26.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1963.', acceleration='15.5', model='74', origin='Europe')
# Record(car='Opel Manta', mpg='26.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='2300.', acceleration='14.5', model='74', origin='Europe')
# Record(car='Toyota Corolla', mpg='31.0', cylinders='4', displacement='76.00', horsepower='52.00', weight='1649.', acceleration='16.5', model='74', origin='Japan')
# Record(car='Datsun 710', mpg='32.0', cylinders='4', displacement='83.00', horsepower='61.00', weight='2003.', acceleration='19.0', model='74', origin='Japan')
# Record(car='Dodge Colt', mpg='28.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2125.', acceleration='14.5', model='74', origin='US')
# Record(car='Fiat 128', mpg='24.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2108.', acceleration='15.5', model='74', origin='Europe')
# Record(car='Fiat 124 TC', mpg='26.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2246.', acceleration='14.0', model='74', origin='Europe')
# Record(car='Honda Civic', mpg='24.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2489.', acceleration='15.0', model='74', origin='Japan')
# Record(car='Subaru', mpg='26.0', cylinders='4', displacement='108.0', horsepower='93.00', weight='2391.', acceleration='15.5', model='74', origin='Japan')
# Record(car='Fiat x1.9', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='2000.', acceleration='16.0', model='74', origin='Europe')
# Record(car='Plymouth Valiant Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3264.', acceleration='16.0', model='75', origin='US')
# Record(car='Chevrolet Nova', mpg='18.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3459.', acceleration='16.0', model='75', origin='US')
# Record(car='Mercury Monarch', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3432.', acceleration='21.0', model='75', origin='US')
# Record(car='Ford Maverick', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3158.', acceleration='19.5', model='75', origin='US')
# Record(car='Pontiac Catalina', mpg='16.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4668.', acceleration='11.5', model='75', origin='US')
# Record(car='Chevrolet Bel Air', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4440.', acceleration='14.0', model='75', origin='US')
# Record(car='Plymouth Grand Fury', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4498.', acceleration='14.5', model='75', origin='US')
# Record(car='Ford LTD', mpg='14.0', cylinders='8', displacement='351.0', horsepower='148.0', weight='4657.', acceleration='13.5', model='75', origin='US')
# Record(car='Buick Century', mpg='17.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3907.', acceleration='21.0', model='75', origin='US')
# Record(car='Chevrolete Chevelle Malibu', mpg='16.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3897.', acceleration='18.5', model='75', origin='US')
# Record(car='AMC Matador', mpg='15.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3730.', acceleration='19.0', model='75', origin='US')
# Record(car='Plymouth Fury', mpg='18.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3785.', acceleration='19.0', model='75', origin='US')
# Record(car='Buick Skyhawk', mpg='21.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3039.', acceleration='15.0', model='75', origin='US')
# Record(car='Chevrolet Monza 2+2', mpg='20.0', cylinders='8', displacement='262.0', horsepower='110.0', weight='3221.', acceleration='13.5', model='75', origin='US')
# Record(car='Ford Mustang II', mpg='13.0', cylinders='8', displacement='302.0', horsepower='129.0', weight='3169.', acceleration='12.0', model='75', origin='US')
# Record(car='Toyota Corolla', mpg='29.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2171.', acceleration='16.0', model='75', origin='Japan')
# Record(car='Ford Pinto', mpg='23.0', cylinders='4', displacement='140.0', horsepower='83.00', weight='2639.', acceleration='17.0', model='75', origin='US')
# Record(car='AMC Gremlin', mpg='20.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2914.', acceleration='16.0', model='75', origin='US')
# Record(car='Pontiac Astro', mpg='23.0', cylinders='4', displacement='140.0', horsepower='78.00', weight='2592.', acceleration='18.5', model='75', origin='US')
# Record(car='Toyota Corolla', mpg='24.0', cylinders='4', displacement='134.0', horsepower='96.00', weight='2702.', acceleration='13.5', model='75', origin='Japan')
# Record(car='Volkswagen Dasher', mpg='25.0', cylinders='4', displacement='90.00', horsepower='71.00', weight='2223.', acceleration='16.5', model='75', origin='Europe')
# Record(car='Datsun 710', mpg='24.0', cylinders='4', displacement='119.0', horsepower='97.00', weight='2545.', acceleration='17.0', model='75', origin='Japan')
# Record(car='Ford Pinto', mpg='18.0', cylinders='6', displacement='171.0', horsepower='97.00', weight='2984.', acceleration='14.5', model='75', origin='US')
# Record(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.0', model='75', origin='Europe')
# Record(car='AMC Pacer', mpg='19.0', cylinders='6', displacement='232.0', horsepower='90.00', weight='3211.', acceleration='17.0', model='75', origin='US')
# Record(car='Audi 100LS', mpg='23.0', cylinders='4', displacement='115.0', horsepower='95.00', weight='2694.', acceleration='15.0', model='75', origin='Europe')
# Record(car='Peugeot 504', mpg='23.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='2957.', acceleration='17.0', model='75', origin='Europe')
# Record(car='Volvo 244DL', mpg='22.0', cylinders='4', displacement='121.0', horsepower='98.00', weight='2945.', acceleration='14.5', model='75', origin='Europe')
# Record(car='Saab 99LE', mpg='25.0', cylinders='4', displacement='121.0', horsepower='115.0', weight='2671.', acceleration='13.5', model='75', origin='Europe')
# Record(car='Honda Civic CVCC', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.5', model='75', origin='Japan')
# Record(car='Fiat 131', mpg='28.0', cylinders='4', displacement='107.0', horsepower='86.00', weight='2464.', acceleration='15.5', model='76', origin='Europe')
# Record(car='Opel 1900', mpg='25.0', cylinders='4', displacement='116.0', horsepower='81.00', weight='2220.', acceleration='16.9', model='76', origin='Europe')
# Record(car='Capri ii', mpg='25.0', cylinders='4', displacement='140.0', horsepower='92.00', weight='2572.', acceleration='14.9', model='76', origin='US')
# Record(car='Dodge Colt', mpg='26.0', cylinders='4', displacement='98.00', horsepower='79.00', weight='2255.', acceleration='17.7', model='76', origin='US')
# Record(car='Renault 12tl', mpg='27.0', cylinders='4', displacement='101.0', horsepower='83.00', weight='2202.', acceleration='15.3', model='76', origin='Europe')
# Record(car='Chevrolet Chevelle Malibu Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='140.0', weight='4215.', acceleration='13.0', model='76', origin='US')
# Record(car='Dodge Coronet Brougham', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4190.', acceleration='13.0', model='76', origin='US')
# Record(car='AMC Matador', mpg='15.5', cylinders='8', displacement='304.0', horsepower='120.0', weight='3962.', acceleration='13.9', model='76', origin='US')
# Record(car='Ford Gran Torino', mpg='14.5', cylinders='8', displacement='351.0', horsepower='152.0', weight='4215.', acceleration='12.8', model='76', origin='US')
# Record(car='Plymouth Valiant', mpg='22.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3233.', acceleration='15.4', model='76', origin='US')
# Record(car='Chevrolet Nova', mpg='22.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3353.', acceleration='14.5', model='76', origin='US')
# Record(car='Ford Maverick', mpg='24.0', cylinders='6', displacement='200.0', horsepower='81.00', weight='3012.', acceleration='17.6', model='76', origin='US')
# Record(car='AMC Hornet', mpg='22.5', cylinders='6', displacement='232.0', horsepower='90.00', weight='3085.', acceleration='17.6', model='76', origin='US')
# Record(car='Chevrolet Chevette', mpg='29.0', cylinders='4', displacement='85.00', horsepower='52.00', weight='2035.', acceleration='22.2', model='76', origin='US')
# Record(car='Chevrolet Woody', mpg='24.5', cylinders='4', displacement='98.00', horsepower='60.00', weight='2164.', acceleration='22.1', model='76', origin='US')
# Record(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.2', model='76', origin='Europe')
# Record(car='Honda Civic', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.4', model='76', origin='Japan')
# Record(car='Dodge Aspen SE', mpg='20.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3651.', acceleration='17.7', model='76', origin='US')
# Record(car='Ford Grenada ghia', mpg='18.0', cylinders='6', displacement='250.0', horsepower='78.00', weight='3574.', acceleration='21.0', model='76', origin='US')
# Record(car='Pontiac Ventura SJ', mpg='18.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3645.', acceleration='16.2', model='76', origin='US')
# Record(car='AMC Pacer d/l', mpg='17.5', cylinders='6', displacement='258.0', horsepower='95.00', weight='3193.', acceleration='17.8', model='76', origin='US')
# Record(car='Volkswagen Rabbit', mpg='29.5', cylinders='4', displacement='97.00', horsepower='71.00', weight='1825.', acceleration='12.2', model='76', origin='Europe')
# Record(car='Datsun B-210', mpg='32.0', cylinders='4', displacement='85.00', horsepower='70.00', weight='1990.', acceleration='17.0', model='76', origin='Japan')
# Record(car='Toyota Corolla', mpg='28.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2155.', acceleration='16.4', model='76', origin='Japan')
# Record(car='Ford Pinto', mpg='26.5', cylinders='4', displacement='140.0', horsepower='72.00', weight='2565.', acceleration='13.6', model='76', origin='US')
# Record(car='Volvo 245', mpg='20.0', cylinders='4', displacement='130.0', horsepower='102.0', weight='3150.', acceleration='15.7', model='76', origin='Europe')
# Record(car='Plymouth Volare Premier v8', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3940.', acceleration='13.2', model='76', origin='US')
# Record(car='Peugeot 504', mpg='19.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='3270.', acceleration='21.9', model='76', origin='Europe')
# Record(car='Toyota Mark II', mpg='19.0', cylinders='6', displacement='156.0', horsepower='108.0', weight='2930.', acceleration='15.5', model='76', origin='Japan')
# Record(car='Mercedes-Benz 280s', mpg='16.5', cylinders='6', displacement='168.0', horsepower='120.0', weight='3820.', acceleration='16.7', model='76', origin='Europe')
# Record(car='Cadillac Seville', mpg='16.5', cylinders='8', displacement='350.0', horsepower='180.0', weight='4380.', acceleration='12.1', model='76', origin='US')
# Record(car='Chevrolet C10', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4055.', acceleration='12.0', model='76', origin='US')
# Record(car='Ford F108', mpg='13.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='3870.', acceleration='15.0', model='76', origin='US')
# Record(car='Dodge D100', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3755.', acceleration='14.0', model='76', origin='US')
# Record(car='Honda Accord CVCC', mpg='31.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2045.', acceleration='18.5', model='77', origin='Japan')
# Record(car='Buick Opel Isuzu Deluxe', mpg='30.0', cylinders='4', displacement='111.0', horsepower='80.00', weight='2155.', acceleration='14.8', model='77', origin='US')
# Record(car='Renault 5 GTL', mpg='36.0', cylinders='4', displacement='79.00', horsepower='58.00', weight='1825.', acceleration='18.6', model='77', origin='Europe')
# Record(car='Plymouth Arrow GS', mpg='25.5', cylinders='4', displacement='122.0', horsepower='96.00', weight='2300.', acceleration='15.5', model='77', origin='US')
# Record(car='Datsun F-10 Hatchback', mpg='33.5', cylinders='4', displacement='85.00', horsepower='70.00', weight='1945.', acceleration='16.8', model='77', origin='Japan')
# Record(car='Chevrolet Caprice Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='145.0', weight='3880.', acceleration='12.5', model='77', origin='US')
# Record(car='Oldsmobile Cutlass Supreme', mpg='17.0', cylinders='8', displacement='260.0', horsepower='110.0', weight='4060.', acceleration='19.0', model='77', origin='US')
# Record(car='Dodge Monaco Brougham', mpg='15.5', cylinders='8', displacement='318.0', horsepower='145.0', weight='4140.', acceleration='13.7', model='77', origin='US')
# Record(car='Mercury Cougar Brougham', mpg='15.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='4295.', acceleration='14.9', model='77', origin='US')
# Record(car='Chevrolet Concours', mpg='17.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3520.', acceleration='16.4', model='77', origin='US')
# Record(car='Buick Skylark', mpg='20.5', cylinders='6', displacement='231.0', horsepower='105.0', weight='3425.', acceleration='16.9', model='77', origin='US')
# Record(car='Plymouth Volare Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3630.', acceleration='17.7', model='77', origin='US')
# Record(car='Ford Grenada', mpg='18.5', cylinders='6', displacement='250.0', horsepower='98.00', weight='3525.', acceleration='19.0', model='77', origin='US')
# Record(car='Pontiac Grand Prix LJ', mpg='16.0', cylinders='8', displacement='400.0', horsepower='180.0', weight='4220.', acceleration='11.1', model='77', origin='US')
# Record(car='Chevrolet Monte Carlo Landau', mpg='15.5', cylinders='8', displacement='350.0', horsepower='170.0', weight='4165.', acceleration='11.4', model='77', origin='US')
# Record(car='Chrysler Cordoba', mpg='15.5', cylinders='8', displacement='400.0', horsepower='190.0', weight='4325.', acceleration='12.2', model='77', origin='US')
# Record(car='Ford Thunderbird', mpg='16.0', cylinders='8', displacement='351.0', horsepower='149.0', weight='4335.', acceleration='14.5', model='77', origin='US')
# Record(car='Volkswagen Rabbit Custom', mpg='29.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='1940.', acceleration='14.5', model='77', origin='Europe')
# Record(car='Pontiac Sunbird Coupe', mpg='24.5', cylinders='4', displacement='151.0', horsepower='88.00', weight='2740.', acceleration='16.0', model='77', origin='US')
# Record(car='Toyota Corolla Liftback', mpg='26.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2265.', acceleration='18.2', model='77', origin='Japan')
# Record(car='Ford Mustang II 2+2', mpg='25.5', cylinders='4', displacement='140.0', horsepower='89.00', weight='2755.', acceleration='15.8', model='77', origin='US')
# Record(car='Chevrolet Chevette', mpg='30.5', cylinders='4', displacement='98.00', horsepower='63.00', weight='2051.', acceleration='17.0', model='77', origin='US')
# Record(car='Dodge Colt m/m', mpg='33.5', cylinders='4', displacement='98.00', horsepower='83.00', weight='2075.', acceleration='15.9', model='77', origin='US')
# Record(car='Subaru DL', mpg='30.0', cylinders='4', displacement='97.00', horsepower='67.00', weight='1985.', acceleration='16.4', model='77', origin='Japan')
# Record(car='Volkswagen Dasher', mpg='30.5', cylinders='4', displacement='97.00', horsepower='78.00', weight='2190.', acceleration='14.1', model='77', origin='Europe')
# Record(car='Datsun 810', mpg='22.0', cylinders='6', displacement='146.0', horsepower='97.00', weight='2815.', acceleration='14.5', model='77', origin='Japan')
# Record(car='BMW 320i', mpg='21.5', cylinders='4', displacement='121.0', horsepower='110.0', weight='2600.', acceleration='12.8', model='77', origin='Europe')
# Record(car='Mazda RX-4', mpg='21.5', cylinders='3', displacement='80.00', horsepower='110.0', weight='2720.', acceleration='13.5', model='77', origin='Japan')
# Record(car='Volkswagen Rabbit Custom Diesel', mpg='43.1', cylinders='4', displacement='90.00', horsepower='48.00', weight='1985.', acceleration='21.5', model='78', origin='Europe')
# Record(car='Ford Fiesta', mpg='36.1', cylinders='4', displacement='98.00', horsepower='66.00', weight='1800.', acceleration='14.4', model='78', origin='US')
# Record(car='Mazda GLC Deluxe', mpg='32.8', cylinders='4', displacement='78.00', horsepower='52.00', weight='1985.', acceleration='19.4', model='78', origin='Japan')
# Record(car='Datsun B210 GX', mpg='39.4', cylinders='4', displacement='85.00', horsepower='70.00', weight='2070.', acceleration='18.6', model='78', origin='Japan')
# Record(car='Honda Civic CVCC', mpg='36.1', cylinders='4', displacement='91.00', horsepower='60.00', weight='1800.', acceleration='16.4', model='78', origin='Japan')
# Record(car='Oldsmobile Cutlass Salon Brougham', mpg='19.9', cylinders='8', displacement='260.0', horsepower='110.0', weight='3365.', acceleration='15.5', model='78', origin='US')
# Record(car='Dodge Diplomat', mpg='19.4', cylinders='8', displacement='318.0', horsepower='140.0', weight='3735.', acceleration='13.2', model='78', origin='US')
# Record(car='Mercury Monarch ghia', mpg='20.2', cylinders='8', displacement='302.0', horsepower='139.0', weight='3570.', acceleration='12.8', model='78', origin='US')
# Record(car='Pontiac Phoenix LJ', mpg='19.2', cylinders='6', displacement='231.0', horsepower='105.0', weight='3535.', acceleration='19.2', model='78', origin='US')
# Record(car='Chevrolet Malibu', mpg='20.5', cylinders='6', displacement='200.0', horsepower='95.00', weight='3155.', acceleration='18.2', model='78', origin='US')
# Record(car='Ford Fairmont (auto)', mpg='20.2', cylinders='6', displacement='200.0', horsepower='85.00', weight='2965.', acceleration='15.8', model='78', origin='US')
# Record(car='Ford Fairmont (man)', mpg='25.1', cylinders='4', displacement='140.0', horsepower='88.00', weight='2720.', acceleration='15.4', model='78', origin='US')
# Record(car='Plymouth Volare', mpg='20.5', cylinders='6', displacement='225.0', horsepower='100.0', weight='3430.', acceleration='17.2', model='78', origin='US')
# Record(car='AMC Concord', mpg='19.4', cylinders='6', displacement='232.0', horsepower='90.00', weight='3210.', acceleration='17.2', model='78', origin='US')
# Record(car='Buick Century Special', mpg='20.6', cylinders='6', displacement='231.0', horsepower='105.0', weight='3380.', acceleration='15.8', model='78', origin='US')
# Record(car='Mercury Zephyr', mpg='20.8', cylinders='6', displacement='200.0', horsepower='85.00', weight='3070.', acceleration='16.7', model='78', origin='US')
# Record(car='Dodge Aspen', mpg='18.6', cylinders='6', displacement='225.0', horsepower='110.0', weight='3620.', acceleration='18.7', model='78', origin='US')
# Record(car='AMC Concord d/l', mpg='18.1', cylinders='6', displacement='258.0', horsepower='120.0', weight='3410.', acceleration='15.1', model='78', origin='US')
# Record(car='Chevrolet Monte Carlo Landau', mpg='19.2', cylinders='8', displacement='305.0', horsepower='145.0', weight='3425.', acceleration='13.2', model='78', origin='US')
# Record(car='Buick Regal Sport Coupe (turbo)', mpg='17.7', cylinders='6', displacement='231.0', horsepower='165.0', weight='3445.', acceleration='13.4', model='78', origin='US')
# Record(car='Ford Futura', mpg='18.1', cylinders='8', displacement='302.0', horsepower='139.0', weight='3205.', acceleration='11.2', model='78', origin='US')
# Record(car='Dodge Magnum XE', mpg='17.5', cylinders='8', displacement='318.0', horsepower='140.0', weight='4080.', acceleration='13.7', model='78', origin='US')
# Record(car='Chevrolet Chevette', mpg='30.0', cylinders='4', displacement='98.00', horsepower='68.00', weight='2155.', acceleration='16.5', model='78', origin='US')
# Record(car='Toyota Corolla', mpg='27.5', cylinders='4', displacement='134.0', horsepower='95.00', weight='2560.', acceleration='14.2', model='78', origin='Japan')
# Record(car='Datsun 510', mpg='27.2', cylinders='4', displacement='119.0', horsepower='97.00', weight='2300.', acceleration='14.7', model='78', origin='Japan')
# Record(car='Dodge Omni', mpg='30.9', cylinders='4', displacement='105.0', horsepower='75.00', weight='2230.', acceleration='14.5', model='78', origin='US')
# Record(car='Toyota Celica GT Liftback', mpg='21.1', cylinders='4', displacement='134.0', horsepower='95.00', weight='2515.', acceleration='14.8', model='78', origin='Japan')
# Record(car='Plymouth Sapporo', mpg='23.2', cylinders='4', displacement='156.0', horsepower='105.0', weight='2745.', acceleration='16.7', model='78', origin='US')
# Record(car='Oldsmobile Starfire SX', mpg='23.8', cylinders='4', displacement='151.0', horsepower='85.00', weight='2855.', acceleration='17.6', model='78', origin='US')
# Record(car='Datsun 200-SX', mpg='23.9', cylinders='4', displacement='119.0', horsepower='97.00', weight='2405.', acceleration='14.9', model='78', origin='Japan')
# Record(car='Audi 5000', mpg='20.3', cylinders='5', displacement='131.0', horsepower='103.0', weight='2830.', acceleration='15.9', model='78', origin='Europe')
# Record(car='Volvo 264gl', mpg='17.0', cylinders='6', displacement='163.0', horsepower='125.0', weight='3140.', acceleration='13.6', model='78', origin='Europe')
# Record(car='Saab 99gle', mpg='21.6', cylinders='4', displacement='121.0', horsepower='115.0', weight='2795.', acceleration='15.7', model='78', origin='Europe')
# Record(car='Peugeot 604sl', mpg='16.2', cylinders='6', displacement='163.0', horsepower='133.0', weight='3410.', acceleration='15.8', model='78', origin='Europe')
# Record(car='Volkswagen Scirocco', mpg='31.5', cylinders='4', displacement='89.00', horsepower='71.00', weight='1990.', acceleration='14.9', model='78', origin='Europe')
# Record(car='Honda Accord LX', mpg='29.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2135.', acceleration='16.6', model='78', origin='Japan')
# Record(car='Pontiac Lemans V6', mpg='21.5', cylinders='6', displacement='231.0', horsepower='115.0', weight='3245.', acceleration='15.4', model='79', origin='US')
# Record(car='Mercury Zephyr 6', mpg='19.8', cylinders='6', displacement='200.0', horsepower='85.00', weight='2990.', acceleration='18.2', model='79', origin='US')
# Record(car='Ford Fairmont 4', mpg='22.3', cylinders='4', displacement='140.0', horsepower='88.00', weight='2890.', acceleration='17.3', model='79', origin='US')
# Record(car='AMC Concord DL 6', mpg='20.2', cylinders='6', displacement='232.0', horsepower='90.00', weight='3265.', acceleration='18.2', model='79', origin='US')
# Record(car='Dodge Aspen 6', mpg='20.6', cylinders='6', displacement='225.0', horsepower='110.0', weight='3360.', acceleration='16.6', model='79', origin='US')
# Record(car='Chevrolet Caprice Classic', mpg='17.0', cylinders='8', displacement='305.0', horsepower='130.0', weight='3840.', acceleration='15.4', model='79', origin='US')
# Record(car='Ford LTD Landau', mpg='17.6', cylinders='8', displacement='302.0', horsepower='129.0', weight='3725.', acceleration='13.4', model='79', origin='US')
# ...
# Record(ssn='773-21-9639', first_name='Brittney', last_name='Byart', gender='Female', language='Tok Pisin')
# Record(ssn='773-53-7438', first_name='Flo', last_name='Sirmond', gender='Female', language='Khmer')
# Record(ssn='773-82-1734', first_name='Maris', last_name='Currin', gender='Female', language='Armenian')
# Record(ssn='774-08-5376', first_name='Pam', last_name='Matterface', gender='Female', language='Swahili')
# Record(ssn='775-09-9949', first_name='Orlando', last_name='Gresley', gender='Male', language='Danish')
# Record(ssn='777-05-1491', first_name='Devora', last_name='Ashbridge', gender='Female', language='Somali')
# Record(ssn='777-68-2978', first_name='Mignon', last_name='Skottle', gender='Female', language='Northern Sotho')
# Record(ssn='777-94-4586', first_name='Siward', last_name='Blues', gender='Male', language='Thai')
# Record(ssn='778-74-8262', first_name='Sonia', last_name='Grishakin', gender='Female', language='Bulgarian')
# Record(ssn='779-59-1449', first_name='Gertrude', last_name='Ledamun', gender='Female', language='Hungarian')
# Record(ssn='780-69-8282', first_name='Sibeal', last_name='Dawney', gender='Female', language='Czech')
# Record(ssn='781-88-2076', first_name='Gelya', last_name='Stell', gender='Female', language='Czech')
# Record(ssn='782-46-9660', first_name='Malina', last_name='Julyan', gender='Female', language='Burmese')
# Record(ssn='782-60-6848', first_name='Jehu', last_name='Scholig', gender='Male', language='Polish')
# Record(ssn='783-22-9258', first_name='Modestine', last_name='Cuttings', gender='Female', language='Assamese')
# Record(ssn='784-88-0730', first_name='Baxie', last_name='Judd', gender='Male', language='Maltese')
# Record(ssn='785-14-5978', first_name='Trista', last_name='Watkinson', gender='Female', language='Moldovan')
# Record(ssn='786-56-3561', first_name='Wait', last_name='Boyda', gender='Male', language='Norwegian')
# Record(ssn='786-63-6223', first_name='Adham', last_name='Toope', gender='Male', language='Belarusian')
# Record(ssn='787-05-9008', first_name='Ricki', last_name='Jurges', gender='Female', language='Arabic')
# Record(ssn='787-09-5697', first_name='Chelsea', last_name='Pashby', gender='Female', language='Northern Sotho')
# Record(ssn='787-10-7877', first_name='Torrence', last_name='Tapping', gender='Male', language='Hiri Motu')
# Record(ssn='788-15-2625', first_name='Drusilla', last_name='Bannester', gender='Female', language='Gujarati')
# Record(ssn='789-70-1821', first_name='Denni', last_name='De Biasio', gender='Female', language='Azeri')
# Record(ssn='790-04-1283', first_name='Christyna', last_name='Morrissey', gender='Female', language='Quechua')
# Record(ssn='792-71-8046', first_name='Carly', last_name='Hazley', gender='Female', language='Guarana')
# Record(ssn='794-24-3802', first_name='Esther', last_name='Sayton', gender='Female', language='Somali')
# Record(ssn='795-56-6486', first_name='Stevena', last_name='Vatcher', gender='Female', language='Gagauz')
# Record(ssn='795-77-5263', first_name='Burty', last_name='Frosdick', gender='Male', language='Marathi')
# Record(ssn='797-05-2289', first_name='Fanchon', last_name='Petrushanko', gender='Female', language='Finnish')
# Record(ssn='797-25-9814', first_name='Aleksandr', last_name='Swalwell', gender='Male', language='Pashto')
# Record(ssn='797-65-2382', first_name='Marianne', last_name='Huccaby', gender='Female', language='Swedish')
# Record(ssn='797-87-7992', first_name='Lonna', last_name='Plumridge', gender='Female', language='Armenian')
# Record(ssn='798-34-1082', first_name='Henka', last_name='Synder', gender='Female', language='Italian')
# Record(ssn='798-65-5644', first_name='Irita', last_name='Heady', gender='Female', language='Montenegrin')
# Record(ssn='800-06-9721', first_name='Carter', last_name='Waldron', gender='Male', language='Estonian')
# Record(ssn='801-08-8313', first_name='Aida', last_name='Whitemarsh', gender='Female', language='Chinese')
# Record(ssn='801-92-6460', first_name='Levi', last_name='Downgate', gender='Male', language='Belarusian')
# Record(ssn='801-99-2773', first_name='Justinian', last_name='Carlesso', gender='Male', language='Japanese')
# Record(ssn='804-46-0617', first_name='Geneva', last_name='Crinion', gender='Female', language='Hungarian')
# Record(ssn='807-13-5922', first_name='Vivi', last_name='Edinboro', gender='Female', language='Sotho')
# Record(ssn='807-24-6202', first_name='Lanette', last_name='Elvins', gender='Female', language='Hiri Motu')
# Record(ssn='807-25-6136', first_name='Sammy', last_name='Linnard', gender='Female', language='Dutch')
# Record(ssn='807-35-8936', first_name='Georgi', last_name='Widd', gender='Male', language='Afrikaans')
# Record(ssn='807-50-8539', first_name='Jaquith', last_name='Erdes', gender='Female', language='Dhivehi')
# Record(ssn='807-60-5615', first_name='Michale', last_name='Druery', gender='Male', language='Dhivehi')
# Record(ssn='808-55-8658', first_name='Ursulina', last_name='Kunze', gender='Female', language='Chinese')
# Record(ssn='808-80-2542', first_name='Gustaf', last_name='Hullot', gender='Male', language='Persian')
# Record(ssn='811-65-2750', first_name='Minetta', last_name='Dusting', gender='Female', language='Spanish')
# Record(ssn='812-11-9403', first_name='Carmina', last_name='Turnell', gender='Female', language='West Frisian')
# Record(ssn='813-42-4142', first_name='Killy', last_name='Threadgould', gender='Male', language='Polish')
# Record(ssn='813-47-5215', first_name='Willi', last_name='Collet', gender='Male', language='Gujarati')
# Record(ssn='815-83-0300', first_name='Romeo', last_name='Rayworth', gender='Male', language='Thai')
# Record(ssn='816-31-3858', first_name='Elvera', last_name='Walmsley', gender='Female', language='Montenegrin')
# Record(ssn='816-47-4782', first_name='Wilmer', last_name='Maides', gender='Male', language='Aymara')
# Record(ssn='816-90-2049', first_name='Berry', last_name='Delagnes', gender='Female', language='Bengali')
# Record(ssn='817-04-1950', first_name='Fletcher', last_name='McGrouther', gender='Male', language='Albanian')
# Record(ssn='817-25-7437', first_name='Randall', last_name='Fibbitts', gender='Male', language='Yiddish')
# Record(ssn='817-80-8930', first_name='Lib', last_name='Skein', gender='Female', language='Arabic')
# Record(ssn='818-61-0770', first_name='Stanly', last_name='Casseldine', gender='Male', language='Belarusian')
# Record(ssn='819-52-5886', first_name='Paulette', last_name='McAree', gender='Female', language='Arabic')
# Record(ssn='819-64-1414', first_name='Malynda', last_name='Hundall', gender='Female', language='Filipino')
# Record(ssn='820-96-1105', first_name='Andy', last_name='Sayce', gender='Female', language='Pashto')
# Record(ssn='822-05-9037', first_name='Meggi', last_name='Mapes', gender='Female', language='Moldovan')
# Record(ssn='822-30-4861', first_name='Phyllis', last_name='Cronk', gender='Female', language='Fijian')
# Record(ssn='823-27-0762', first_name='Marten', last_name='McCord', gender='Male', language='Indonesian')
# Record(ssn='823-75-5753', first_name='Thibaut', last_name='Van Schafflaer', gender='Male', language='Chinese')
# Record(ssn='824-89-4169', first_name='Tamqrah', last_name='Goroni', gender='Female', language='Swedish')
# Record(ssn='826-97-8029', first_name='Llewellyn', last_name='Shimwell', gender='Male', language='Belarusian')
# Record(ssn='827-62-4599', first_name='Phyllys', last_name='Akast', gender='Female', language='Armenian')
# Record(ssn='830-23-1573', first_name='Carine', last_name='Abramin', gender='Female', language='Bislama')
# Record(ssn='831-44-3286', first_name='Leesa', last_name='Finci', gender='Female', language='Nepali')
# Record(ssn='833-01-1428', first_name='Ashlan', last_name='Zannotti', gender='Female', language='Finnish')
# Record(ssn='835-54-3785', first_name='Nathaniel', last_name='Wegman', gender='Male', language='Azeri')
# Record(ssn='836-40-1837', first_name='Brocky', last_name='Kewzick', gender='Male', language='Armenian')
# Record(ssn='836-99-3309', first_name='Cobby', last_name='Mutter', gender='Male', language='Georgian')
# Record(ssn='837-76-5619', first_name='Alleyn', last_name='Parade', gender='Male', language='Croatian')
# Record(ssn='838-69-1351', first_name='Alwin', last_name='Hazzard', gender='Male', language='Kannada')
# Record(ssn='840-41-7929', first_name='Sherlock', last_name='Pinshon', gender='Male', language='Khmer')
# Record(ssn='841-64-8517', first_name='Hugues', last_name='Kenealy', gender='Male', language='Korean')
# Record(ssn='842-90-7557', first_name='Brit', last_name='Weall', gender='Female', language='West Frisian')
# Record(ssn='844-15-4668', first_name='Eleonora', last_name='Delete', gender='Female', language='Hiri Motu')
# Record(ssn='844-50-7305', first_name='Merralee', last_name='Orae', gender='Female', language='Macedonian')
# Record(ssn='846-07-1407', first_name='Tobias', last_name='Blakelock', gender='Male', language='German')
# Record(ssn='846-09-9851', first_name='Shani', last_name='Penrose', gender='Female', language='New Zealand Sign Language')
# Record(ssn='846-59-9961', first_name='Saleem', last_name='Osmant', gender='Male', language='Croatian')
# Record(ssn='847-34-4817', first_name='Orazio', last_name='Coners', gender='Male', language='Yiddish')
# Record(ssn='847-61-7656', first_name='Brit', last_name='Lodovichi', gender='Male', language='Bislama')
# Record(ssn='848-58-3386', first_name='Julianne', last_name='Lygo', gender='Female', language='Japanese')
# Record(ssn='848-74-2886', first_name='Helyn', last_name='Witheford', gender='Female', language='Bislama')
# Record(ssn='848-76-8808', first_name='Durward', last_name='Nuscha', gender='Male', language='Nepali')
# Record(ssn='849-31-1551', first_name='Lisabeth', last_name='Mattessen', gender='Female', language='German')
# Record(ssn='849-64-6624', first_name='Hallie', last_name='Proschke', gender='Female', language='Fijian')
# Record(ssn='849-98-2973', first_name='Hurley', last_name='Newart', gender='Male', language='Hindi')
# Record(ssn='851-94-2162', first_name='Rodi', last_name='Mulrenan', gender='Female', language='Catalan')
# Record(ssn='852-15-7707', first_name='Mario', last_name='Lelande', gender='Male', language='Nepali')
# Record(ssn='853-11-8953', first_name='Brice', last_name='Kyd', gender='Male', language='Dari')
# Record(ssn='853-47-3648', first_name='Olag', last_name='Belhome', gender='Male', language='Maltese')
# Record(ssn='854-68-7635', first_name='Eyde', last_name='McCunn', gender='Female', language='Moldovan')
# Record(ssn='854-71-2983', first_name='Rikki', last_name='Loveland', gender='Male', language='Dutch')
# Record(ssn='854-79-5334', first_name='Bevan', last_name='Kolczynski', gender='Male', language='Swahili')
# Record(ssn='856-18-3980', first_name='Neale', last_name='Sesser', gender='Male', language='Maltese')
# Record(ssn='856-27-9112', first_name='Virgilio', last_name='Kirrage', gender='Male', language='Pashto')
# Record(ssn='856-67-4080', first_name='Aggy', last_name='Cobley', gender='Female', language='Dhivehi')
# Record(ssn='857-37-5902', first_name='Jenni', last_name='Swinyard', gender='Female', language='Hindi')
# Record(ssn='858-03-7735', first_name='Allayne', last_name='Wardingley', gender='Male', language='Kazakh')
# Record(ssn='858-27-9190', first_name='Yuri', last_name='Sixsmith', gender='Male', language='Norwegian')
# Record(ssn='860-67-0256', first_name='Bendicty', last_name='Lindgren', gender='Male', language='Tajik')
# Record(ssn='860-89-2570', first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish')
# Record(ssn='861-50-6716', first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian')
# Record(ssn='862-20-0653', first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish')
# Record(ssn='864-22-9364', first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian')
# Record(ssn='864-91-7489', first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama')
# Record(ssn='866-18-1440', first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento')
# Record(ssn='866-53-0625', first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian')
# Record(ssn='867-11-6007', first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam')
# Record(ssn='867-13-6844', first_name='Clo', last_name='Skacel', gender='Female', language='Armenian')
# Record(ssn='867-88-2360', first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha')
# Record(ssn='868-32-1805', first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian')
# Record(ssn='870-12-6609', first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana')
# Record(ssn='870-93-1121', first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew')
# Record(ssn='871-99-3191', first_name='Susann', last_name='Walrond', gender='Female', language='Amharic')
# Record(ssn='872-18-9267', first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese')
# Record(ssn='872-49-1288', first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish')
# Record(ssn='873-36-4733', first_name='Locke', last_name='Staries', gender='Male', language='Moldovan')
# Record(ssn='875-18-9454', first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu')
# Record(ssn='875-75-0495', first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish')
# Record(ssn='878-12-8265', first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi')
# Record(ssn='880-22-4449', first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri')
# Record(ssn='881-19-5974', first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho')
# Record(ssn='881-88-7308', first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga')
# Record(ssn='881-95-7180', first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian')
# Record(ssn='882-49-5290', first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian')
# Record(ssn='884-61-1852', first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian')
# Record(ssn='887-41-7878', first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil')
# Record(ssn='887-83-9002', first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin')
# Record(ssn='888-50-7008', first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha')
# Record(ssn='888-53-7684', first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian')
# Record(ssn='888-82-4928', first_name='Billye', last_name='Legat', gender='Female', language='Icelandic')
# Record(ssn='890-28-9962', first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua')
# Record(ssn='893-12-0901', first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya')
# Record(ssn='893-17-7318', first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz')
# Record(ssn='894-81-0628', first_name='Ree', last_name='Mordue', gender='Female', language='Tswana')
# Record(ssn='895-26-1658', first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic')
# Record(ssn='895-26-5515', first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho')
# Record(ssn='897-76-7070', first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali')
# Record(ssn='898-03-3165', first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic')
# Record(ssn='898-86-8860', first_name='Hershel', last_name='Few', gender='Male', language='Gagauz')
# Record(ssn='899-09-1766', first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino')
# Record(ssn='899-39-7179', first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek')
# Record(ssn='899-39-7378', first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian')
# Record(ssn='899-47-6116', first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum')
# -------------------
